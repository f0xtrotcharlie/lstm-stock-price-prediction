# %% [markdown]
# # Saving to db from EODHD

# %%
import os
import sqlite3
import pandas as pd
import requests

# EOD API Token and URL
YOUR_API_TOKEN = '64ba54ca4a54b5.70340846'
eod_url = f'https://eodhd.com/api/eod-bulk-last-day/US?api_token={YOUR_API_TOKEN}&fmt=json'

# Define the SQLite database file path
db_path = "..\\data\\stock_data.db"  # Replace with your desired directory and file name
os.makedirs(os.path.dirname(db_path), exist_ok=True)  # Ensure the directory exists

# Function to save DataFrame to SQLite database
def save_to_db(df, connection):
    try:
        # Rename columns for SQLite compatibility
        df.rename(columns={
            "adjusted_close": "Adj_Close",
            "date": "Date",
            "open": "Open",
            "high": "High",
            "low": "Low",
            "close": "Close",
            "volume": "Volume",
            "code": "Ticker"
        }, inplace=True)

        # Ensure DataFrame has all required columns
        df = df[["Date", "Ticker", "Open", "High", "Low", "Close", "Adj_Close", "Volume"]]

        # Save to SQLite database
        df.to_sql("stock_data", connection, if_exists="append", index=False)
        print("Data successfully saved to the database.")

    except Exception as e:
        print(f"Error saving data to database: {str(e)}")

# Function to download data from EOD API and save to SQLite
def download_eod_data(connection):
    try:
        print("Downloading data from EOD API...")

        # Fetch data from the API
        response = requests.get(eod_url)
        response.raise_for_status()
        data = response.json()

        # Convert to DataFrame
        df = pd.DataFrame(data)

        # Save to database
        save_to_db(df, connection)

    except Exception as e:
        print(f"Error downloading EOD data: {str(e)}")

# Main function
def main():
    print("Starting stock data download from EOD API...")

    # Connect to SQLite database
    with sqlite3.connect(db_path) as conn:
        # Create table schema if it doesn't exist
        conn.execute("""
        CREATE TABLE IF NOT EXISTS stock_data (
            Date TEXT,
            Ticker TEXT,
            Open REAL,
            High REAL,
            Low REAL,
            Close REAL,
            Adj_Close REAL,
            Volume INTEGER
        );
        """)

        # Download EOD API data
        download_eod_data(conn)

    print("\nDownload Summary:")
    print("All stock data has been downloaded and saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Starting stock data download from EOD API...
# Downloading data from EOD API...
# Data successfully saved to the database.
#
# Download Summary:
# All stock data has been downloaded and saved successfully.

# %%
import sqlite3
import pandas as pd

# connect to the database
# con = sqlite3.connect(r"Z:\Data\sp500_data\Scripts\sp500_market_data.db")
con = sqlite3.connect(r"C:\Users\Jonat\Documents\GitHub\lstm-stock-price-prediction\data\stock_data.db")

# pd.read_sql_query("SELECT * FROM stock_data WHERE symbol = 'PANW'", con)
df = pd.read_sql_query("SELECT * FROM stock_data WHERE Ticker LIKE 'GOOGL'", con)
df = pd.read_sql_query("SELECT * FROM stock_data ", con)
con.close()
df
# Out:
#                      Date Ticker        Open        High         Low  \
# 0     2010-01-04 00:00:00  GOOGL   15.689439   15.753504   15.621622
# 1     2010-01-05 00:00:00  GOOGL   15.695195   15.711712   15.554054
# 2     2010-01-06 00:00:00  GOOGL   15.662162   15.662162   15.174174
# 3     2010-01-07 00:00:00  GOOGL   15.250250   15.265265   14.831081
# 4     2010-01-08 00:00:00  GOOGL   14.814815   15.096346   14.742492
# ...                   ...    ...         ...         ...         ...
# 3760  2024-12-11 00:00:00  GOOGL  185.309998  195.610001  184.850006
# 3761  2024-12-12 00:00:00  GOOGL  195.000000  195.179993  191.710007
# 3762  2024-12-13 00:00:00  GOOGL  191.009995  192.729996  189.639999
# 3763  2024-12-16 00:00:00  GOOGL  192.869995  199.000000  192.619995
# 3764           2024-12-17  GOOGL  197.250000  201.420000  194.980000
#
#            Close   Adj_Close     Volume
# 0      15.684434   15.627782   78169752
# 1      15.615365   15.558963  120067812
# 2      15.221722   15.166740  158988852
# 3      14.867367   14.813666  256315428
# 4      15.065566   15.011149  188783028
# ...          ...         ...        ...
# 3760  195.399994  195.399994   67894100
# 3761  191.960007  191.960007   34817500
# 3762  189.820007  189.820007   25143500
# 3763  196.660004  196.660004   44934900
# 3764  195.420000  195.420000   43504025
#
# [3765 rows x 8 columns]

# %%
df[df['Ticker'] == 'GOOGL']
# Out:
#                       Date Ticker        Open        High         Low  \
# 0      2010-01-04 00:00:00  GOOGL   15.689439   15.753504   15.621622
# 1      2010-01-05 00:00:00  GOOGL   15.695195   15.711712   15.554054
# 2      2010-01-06 00:00:00  GOOGL   15.662162   15.662162   15.174174
# 3      2010-01-07 00:00:00  GOOGL   15.250250   15.265265   14.831081
# 4      2010-01-08 00:00:00  GOOGL   14.814815   15.096346   14.742492
# ...                    ...    ...         ...         ...         ...
# 3760   2024-12-11 00:00:00  GOOGL  185.309998  195.610001  184.850006
# 3761   2024-12-12 00:00:00  GOOGL  195.000000  195.179993  191.710007
# 3762   2024-12-13 00:00:00  GOOGL  191.009995  192.729996  189.639999
# 3763   2024-12-16 00:00:00  GOOGL  192.869995  199.000000  192.619995
# 25200           2024-12-17  GOOGL  197.250000  201.420000  194.980000
#
#             Close   Adj_Close     Volume
# 0       15.684434   15.627782   78169752
# 1       15.615365   15.558963  120067812
# 2       15.221722   15.166740  158988852
# 3       14.867367   14.813666  256315428
# 4       15.065566   15.011149  188783028
# ...           ...         ...        ...
# 3760   195.399994  195.399994   67894100
# 3761   191.960007  191.960007   34817500
# 3762   189.820007  189.820007   25143500
# 3763   196.660004  196.660004   44934900
# 25200  195.420000  195.420000   43504025
#
# [3765 rows x 8 columns]

# %% [markdown]
# # Saving into sqlite db

# %%
import os
import sqlite3
import pandas as pd
import yfinance as yf
from tqdm import tqdm

# List of stock tickers to download
stock_list = ["GOOGL", "AAPL"]  # Add your desired tickers here

# Define the SQLite database file path
db_path = "..\\data\\stock_data.db"  # Replace with your desired directory and file name
os.makedirs(os.path.dirname(db_path), exist_ok=True)  # Ensure the directory exists

# Define the date range for stock data
start_date = '2010-01-01'
end_date = '2024-12-17'

# Function to download stock data and save it to SQLite
def download_and_save_to_db(ticker, connection):
    try:
        print(f"Downloading data for {ticker}...")

        # Download stock data
        stock_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
        stock_data.columns = stock_data.columns.droplevel(1)

        # Validate that data was retrieved
        if stock_data.empty:
            raise ValueError(f"No data found for {ticker}")

        # Add a ticker column
        stock_data["Ticker"] = ticker

        # Reset index to make 'Date' a column
        stock_data.reset_index(inplace=True)

        # Rename columns for SQLite compatibility
        stock_data.rename(columns={
            "Adj Close": "Adj_Close",
            "Date": "Date",
            "Open": "Open",
            "High": "High",
            "Low": "Low",
            "Close": "Close",
            "Volume": "Volume"
        }, inplace=True)

        # Ensure correct column order and headers
        stock_data = stock_data[
            ["Date", "Ticker", "Open", "High", "Low", "Close", "Adj_Close", "Volume"]
        ]
        # print(stock_data)
        
        # Save to SQLite database
        stock_data.to_sql("stock_data", connection, if_exists="append", index=False)

        print(f"Data for {ticker} saved to database.")

    except Exception as e:
        print(f"Error downloading {ticker}: {str(e)}")

# Main function to iterate through tickers
def main():
    print("Starting sequential stock data download...")

    # Connect to SQLite database
    with sqlite3.connect(db_path) as conn:
        # Create table schema if it doesn't exist
        conn.execute("""
        CREATE TABLE IF NOT EXISTS stock_data (
            Date TEXT,
            Ticker TEXT,
            Open REAL,
            High REAL,
            Low REAL,
            Close REAL,
            Adj_Close REAL,
            Volume INTEGER
        );
        """)

        # Progress bar for the loop
        for ticker in tqdm(stock_list, desc="Downloading Stock Data"):
            download_and_save_to_db(ticker, conn)

    print("\nDownload Summary:")
    print("All stock data has been downloaded and saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Starting sequential stock data download...
# Downloading Stock Data:   0%|                                                                    | 0/2 [00:00<?, ?it/s]
# Downloading data for GOOGL...
# Downloading Stock Data:  50%|██████████████████████████████                              | 1/2 [00:00<00:00,  1.43it/s]
# Price       Date Ticker        Open        High         Low       Close  \
# 0     2010-01-04  GOOGL   15.689439   15.753504   15.621622   15.684434
# 1     2010-01-05  GOOGL   15.695195   15.711712   15.554054   15.615365
# 2     2010-01-06  GOOGL   15.662162   15.662162   15.174174   15.221722
# 3     2010-01-07  GOOGL   15.250250   15.265265   14.831081   14.867367
# 4     2010-01-08  GOOGL   14.814815   15.096346   14.742492   15.065566
# ...          ...    ...         ...         ...         ...         ...
# 3759  2024-12-10  GOOGL  182.850006  186.360001  181.050003  185.169998
# 3760  2024-12-11  GOOGL  185.309998  195.610001  184.850006  195.399994
# 3761  2024-12-12  GOOGL  195.000000  195.179993  191.710007  191.960007
# 3762  2024-12-13  GOOGL  191.009995  192.729996  189.639999  189.820007
# 3763  2024-12-16  GOOGL  192.869995  199.000000  192.619995  196.660004
#
# Price   Adj_Close     Volume
# 0       15.627782   78169752
# 1       15.558963  120067812
# 2       15.166740  158988852
# 3       14.813666  256315428
# 4       15.011149  188783028
# ...           ...        ...
# 3759   185.169998   54813000
# 3760   195.399994   67894100
# 3761   191.960007   34817500
# 3762   189.820007   25143500
# 3763   196.660004   44934900
#
# [3764 rows x 8 columns]
# Data for GOOGL saved to database.
# Downloading data for AAPL...
# Downloading Stock Data: 100%|████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.04it/s]
# Price       Date Ticker        Open        High         Low       Close  \
# 0     2010-01-04   AAPL    7.622500    7.660714    7.585000    7.643214
# 1     2010-01-05   AAPL    7.664286    7.699643    7.616071    7.656429
# 2     2010-01-06   AAPL    7.656429    7.686786    7.526786    7.534643
# 3     2010-01-07   AAPL    7.562500    7.571429    7.466071    7.520714
# 4     2010-01-08   AAPL    7.510714    7.571429    7.466429    7.570714
# ...          ...    ...         ...         ...         ...         ...
# 3759  2024-12-10   AAPL  246.889999  248.210007  245.339996  247.770004
# 3760  2024-12-11   AAPL  247.960007  250.800003  246.259995  246.490005
# 3761  2024-12-12   AAPL  246.889999  248.740005  245.679993  247.960007
# 3762  2024-12-13   AAPL  247.820007  249.289993  246.240005  248.130005
# 3763  2024-12-16   AAPL  247.990005  251.380005  247.649994  251.039993
#
# Price   Adj_Close     Volume
# 0        6.447412  493729600
# 1        6.458559  601904800
# 2        6.355827  552160000
# 3        6.344077  477131200
# 4        6.386254  447610800
# ...           ...        ...
# 3759   247.770004   36914800
# 3760   246.490005   45205800
# 3761   247.960007   32777500
# 3762   248.130005   33155300
# 3763   251.039993   51694800
#
# [3764 rows x 8 columns]
# Data for AAPL saved to database.
#
# Download Summary:
# All stock data has been downloaded and saved successfully.

# %%
import sqlite3
import pandas as pd

# connect to the database
# con = sqlite3.connect(r"Z:\Data\sp500_data\Scripts\sp500_market_data.db")
con = sqlite3.connect(r"C:\Users\Jonat\Documents\GitHub\lstm-stock-price-prediction\data\stock_data.db")
# pd.read_sql_query("SELECT * FROM stock_data WHERE symbol = 'PANW'", con)

df = pd.read_sql_query("SELECT * FROM stock_data", con)
con.close()
df
# Out:
#                      Date Ticker        Open        High         Low  \
# 0     2010-01-04 00:00:00  GOOGL   15.689439   15.753504   15.621622
# 1     2010-01-05 00:00:00  GOOGL   15.695195   15.711712   15.554054
# 2     2010-01-06 00:00:00  GOOGL   15.662162   15.662162   15.174174
# 3     2010-01-07 00:00:00  GOOGL   15.250250   15.265265   14.831081
# 4     2010-01-08 00:00:00  GOOGL   14.814815   15.096346   14.742492
# ...                   ...    ...         ...         ...         ...
# 7523  2024-12-10 00:00:00   AAPL  246.889999  248.210007  245.339996
# 7524  2024-12-11 00:00:00   AAPL  247.960007  250.800003  246.259995
# 7525  2024-12-12 00:00:00   AAPL  246.889999  248.740005  245.679993
# 7526  2024-12-13 00:00:00   AAPL  247.820007  249.289993  246.240005
# 7527  2024-12-16 00:00:00   AAPL  247.990005  251.380005  247.649994
#
#            Close   Adj_Close     Volume
# 0      15.684434   15.627782   78169752
# 1      15.615365   15.558963  120067812
# 2      15.221722   15.166740  158988852
# 3      14.867367   14.813666  256315428
# 4      15.065566   15.011149  188783028
# ...          ...         ...        ...
# 7523  247.770004  247.770004   36914800
# 7524  246.490005  246.490005   45205800
# 7525  247.960007  247.960007   32777500
# 7526  248.130005  248.130005   33155300
# 7527  251.039993  251.039993   51694800
#
# [7528 rows x 8 columns]

# %% [markdown]
# # EOD US Bulk

# %% [markdown]
# $19.99/mo
# 100k API calls/day
# 1k/min
#
# We have API limits 100 000 requests per day. Each symbol request costs 1 API call. For example, multiple tickers request with ten symbols costs 110 API calls;
# however entire exchange request costs 100 API calls.

# %% [markdown]
# https://eodhd.com/financial-apis/bulk-api-eod-splits-dividends?_gl=1*zl7v8c*_gcl_au*ODg0Mjc0Nzc5LjE3MzQ0ODkzMjA.*FPAU*ODg0Mjc0Nzc5LjE3MzQ0ODkzMjA.*_ga*OTQ0NDA1Mjk4LjE3MzQ0ODkzMjA.*_ga_NRYML8NKGH*MTczNDQ4OTMxOC4xLjEuMTczNDQ4OTg4Ny4wLjAuMTA0NDk2MTg5Mw..*_fplc*SFJHcGg1SGklMkI1RGhudkNpWThwQVN4QnpuVzh3ZiUyRk1PamtsV1pEZ0F5VFpjSXlNYk5wU1RyMHVFQ3hYVWolMkY0SUZYSzNwU3dBN2lBOUNvem1LYSUyRlpVR0ZzRFhHcjFuc2klMkZRcWZaU28ycnQ0dW5ZRHdpOE1TOGRKTGxHYnh1dyUzRCUzRA..

# %%
import requests
import pandas as pd
import numpy as np

YOUR_API_TOKEN = '64ba54ca4a54b5.70340846'
url = f'https://eodhd.com/api/eod-bulk-last-day/US?api_token={YOUR_API_TOKEN}&fmt=json'
data = requests.get(url).json()

data
# Out:
# [{'code': '0P0001NGF5',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.4792,
#   'high': 9.4792,
#   'low': 9.4792,
#   'close': 9.4792,
#   'adjusted_close': 9.4792,
#   'volume': 0},
#  {'code': 'A',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 137.58,
#   'high': 139.34,
#   'low': 136.2,
#   'close': 136.46,
#   'adjusted_close': 136.46,
#   'volume': 2430600},
#  {'code': 'AA',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 38,
#   'high': 38.87,
#   'low': 37.53,
#   'close': 38.44,
#   'adjusted_close': 38.44,
#   'volume': 4420300},
#  {'code': 'AAA',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.16,
#   'high': 25.16,
#   'low': 25.13,
#   'close': 25.15,
#   'adjusted_close': 25.15,
#   'volume': 8190},
#  {'code': 'AAAAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.06,
#   'high': 12.06,
#   'low': 12.06,
#   'close': 12.06,
#   'adjusted_close': 12.06,
#   'volume': 0},
#  {'code': 'AAACX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.4,
#   'high': 6.4,
#   'low': 6.4,
#   'close': 6.4,
#   'adjusted_close': 6.4,
#   'volume': 0},
#  {'code': 'AAAGX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.81,
#   'high': 18.81,
#   'low': 18.81,
#   'close': 18.81,
#   'adjusted_close': 18.81,
#   'volume': 0},
#  {'code': 'AAAIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.54,
#   'high': 8.54,
#   'low': 8.54,
#   'close': 8.54,
#   'adjusted_close': 8.54,
#   'volume': 0},
#  {'code': 'AAANX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.16,
#   'high': 16.16,
#   'low': 16.16,
#   'close': 16.16,
#   'adjusted_close': 16.16,
#   'volume': 0},
#  {'code': 'AAAPX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.93,
#   'high': 11.93,
#   'low': 11.93,
#   'close': 11.93,
#   'adjusted_close': 11.93,
#   'volume': 0},
#  {'code': 'AAAQX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.11,
#   'high': 12.11,
#   'low': 12.11,
#   'close': 12.11,
#   'adjusted_close': 12.11,
#   'volume': 0},
#  {'code': 'AAARX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.69,
#   'high': 8.69,
#   'low': 8.69,
#   'close': 8.69,
#   'adjusted_close': 8.69,
#   'volume': 0},
#  {'code': 'AAASX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.97,
#   'high': 11.97,
#   'low': 11.97,
#   'close': 11.97,
#   'adjusted_close': 11.97,
#   'volume': 0},
#  {'code': 'AAATX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.34,
#   'high': 12.34,
#   'low': 12.34,
#   'close': 12.34,
#   'adjusted_close': 12.34,
#   'volume': 0},
#  {'code': 'AAAU',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 26.12,
#   'high': 26.19,
#   'low': 26.06,
#   'close': 26.13,
#   'adjusted_close': 26.13,
#   'volume': 1546900},
#  {'code': 'AAAUX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.51,
#   'high': 8.51,
#   'low': 8.51,
#   'close': 8.51,
#   'adjusted_close': 8.51,
#   'volume': 0},
#  {'code': 'AAAVX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.99,
#   'high': 11.99,
#   'low': 11.99,
#   'close': 11.99,
#   'adjusted_close': 11.99,
#   'volume': 0},
#  {'code': 'AAAZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.98,
#   'high': 11.98,
#   'low': 11.98,
#   'close': 11.98,
#   'adjusted_close': 11.98,
#   'volume': 0},
#  {'code': 'AABB',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0221,
#   'high': 0.025,
#   'low': 0.022,
#   'close': 0.023,
#   'adjusted_close': 0.023,
#   'volume': 5630639},
#  {'code': 'AABCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 17.1,
#   'high': 17.1,
#   'low': 17.1,
#   'close': 17.1,
#   'adjusted_close': 17.1,
#   'volume': 0},
#  {'code': 'AABFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.09,
#   'high': 14.09,
#   'low': 14.09,
#   'close': 14.09,
#   'adjusted_close': 14.09,
#   'volume': 0},
#  {'code': 'AABOX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.45,
#   'high': 8.45,
#   'low': 8.45,
#   'close': 8.45,
#   'adjusted_close': 8.45,
#   'volume': 0},
#  {'code': 'AABPX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.94,
#   'high': 12.94,
#   'low': 12.94,
#   'close': 12.94,
#   'adjusted_close': 12.94,
#   'volume': 0},
#  {'code': 'AABTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 13.03,
#   'high': 13.03,
#   'low': 13.03,
#   'close': 13.03,
#   'adjusted_close': 13.03,
#   'volume': 0},
#  {'code': 'AABVF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.038,
#   'high': 0.038,
#   'low': 0.038,
#   'close': 0.038,
#   'adjusted_close': 0.038,
#   'volume': 2000},
#  {'code': 'AACAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.33,
#   'high': 6.33,
#   'low': 6.33,
#   'close': 6.33,
#   'adjusted_close': 6.33,
#   'volume': 0},
#  {'code': 'AACAY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 4.655,
#   'high': 4.66,
#   'low': 4.65,
#   'close': 4.66,
#   'adjusted_close': 4.66,
#   'volume': 51756},
#  {'code': 'AACCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 5.63,
#   'high': 5.63,
#   'low': 5.63,
#   'close': 5.63,
#   'adjusted_close': 5.63,
#   'volume': 0},
#  {'code': 'AACDX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 5.8,
#   'high': 5.8,
#   'low': 5.8,
#   'close': 5.8,
#   'adjusted_close': 5.8,
#   'volume': 0},
#  {'code': 'AACFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.98,
#   'high': 16.98,
#   'low': 16.98,
#   'close': 16.98,
#   'adjusted_close': 16.98,
#   'volume': 0},
#  {'code': 'AACG',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.9095,
#   'high': 0.9198,
#   'low': 0.856,
#   'close': 0.86,
#   'adjusted_close': 0.86,
#   'volume': 13557},
#  {'code': 'AACGX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 5.8,
#   'high': 5.8,
#   'low': 5.8,
#   'close': 5.8,
#   'adjusted_close': 5.8,
#   'volume': 0},
#  {'code': 'AACRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 5.76,
#   'high': 5.76,
#   'low': 5.76,
#   'close': 5.76,
#   'adjusted_close': 5.76,
#   'volume': 0},
#  {'code': 'AACS',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AACT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.92,
#   'high': 10.95,
#   'low': 10.92,
#   'close': 10.94,
#   'adjusted_close': 10.94,
#   'volume': 241234},
#  {'code': 'AACT-UN',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.91,
#   'high': 10.91,
#   'low': 10.91,
#   'close': 10.91,
#   'adjusted_close': 10.91,
#   'volume': 0},
#  {'code': 'AACT-WT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.18,
#   'high': 0.1999,
#   'low': 0.15,
#   'close': 0.18,
#   'adjusted_close': 0.18,
#   'volume': 771444},
#  {'code': 'AACTF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0175,
#   'high': 0.0175,
#   'low': 0.0174,
#   'close': 0.0174,
#   'adjusted_close': 0.0174,
#   'volume': 20000},
#  {'code': 'AACTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.3,
#   'high': 14.3,
#   'low': 14.3,
#   'close': 14.3,
#   'adjusted_close': 14.3,
#   'volume': 0},
#  {'code': 'AADAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.14,
#   'high': 16.14,
#   'low': 16.14,
#   'close': 16.14,
#   'adjusted_close': 16.14,
#   'volume': 0},
#  {'code': 'AADBX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.95,
#   'high': 15.95,
#   'low': 15.95,
#   'close': 15.95,
#   'adjusted_close': 15.95,
#   'volume': 0},
#  {'code': 'AADCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.65,
#   'high': 15.65,
#   'low': 15.65,
#   'close': 15.65,
#   'adjusted_close': 15.65,
#   'volume': 0},
#  {'code': 'AADEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 30.11,
#   'high': 30.11,
#   'low': 30.11,
#   'close': 30.11,
#   'adjusted_close': 30.11,
#   'volume': 0},
#  {'code': 'AADI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.37,
#   'high': 2.39,
#   'low': 2.25,
#   'close': 2.39,
#   'adjusted_close': 2.39,
#   'volume': 99562},
#  {'code': 'AADIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.32,
#   'high': 16.32,
#   'low': 16.32,
#   'close': 16.32,
#   'adjusted_close': 16.32,
#   'volume': 0},
#  {'code': 'AADR',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 71.51,
#   'high': 71.89,
#   'low': 71.51,
#   'close': 71.88,
#   'adjusted_close': 71.88,
#   'volume': 4700},
#  {'code': 'AADRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.01,
#   'high': 16.01,
#   'low': 16.01,
#   'close': 16.01,
#   'adjusted_close': 16.01,
#   'volume': 0},
#  {'code': 'AADSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.15,
#   'high': 16.15,
#   'low': 16.15,
#   'close': 16.15,
#   'adjusted_close': 16.15,
#   'volume': 0},
#  {'code': 'AADTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.13,
#   'high': 16.13,
#   'low': 16.13,
#   'close': 16.13,
#   'adjusted_close': 16.13,
#   'volume': 0},
#  {'code': 'AADYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.17,
#   'high': 16.17,
#   'low': 16.17,
#   'close': 16.17,
#   'adjusted_close': 16.17,
#   'volume': 0},
#  {'code': 'AAEMX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.93,
#   'high': 10.93,
#   'low': 10.93,
#   'close': 10.93,
#   'adjusted_close': 10.93,
#   'volume': 0},
#  {'code': 'AAENX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.68,
#   'high': 8.68,
#   'low': 8.68,
#   'close': 8.68,
#   'adjusted_close': 8.68,
#   'volume': 0},
#  {'code': 'AAERX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 19,
#   'high': 19,
#   'low': 19,
#   'close': 19,
#   'adjusted_close': 19,
#   'volume': 0},
#  {'code': 'AAESX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.34,
#   'high': 16.34,
#   'low': 16.34,
#   'close': 16.34,
#   'adjusted_close': 16.34,
#   'volume': 0},
#  {'code': 'AAETX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.19,
#   'high': 18.19,
#   'low': 18.19,
#   'close': 18.19,
#   'adjusted_close': 18.19,
#   'volume': 0},
#  {'code': 'AAFRF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.37,
#   'high': 1.37,
#   'low': 1.37,
#   'close': 1.37,
#   'adjusted_close': 1.37,
#   'volume': 0},
#  {'code': 'AAFTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.19,
#   'high': 20.19,
#   'low': 20.19,
#   'close': 20.19,
#   'adjusted_close': 20.19,
#   'volume': 0},
#  {'code': 'AAGC',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0009,
#   'high': 0.001,
#   'low': 0.0008,
#   'close': 0.001,
#   'adjusted_close': 0.001,
#   'volume': 4103763},
#  {'code': 'AAGFF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.311,
#   'high': 0.32,
#   'low': 0.31,
#   'close': 0.32,
#   'adjusted_close': 0.32,
#   'volume': 303500},
#  {'code': 'AAGH',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AAGIY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 28.2,
#   'high': 28.49,
#   'low': 28.2,
#   'close': 28.35,
#   'adjusted_close': 28.35,
#   'volume': 157471},
#  {'code': 'AAGOX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 92.77,
#   'high': 92.77,
#   'low': 92.77,
#   'close': 92.77,
#   'adjusted_close': 92.77,
#   'volume': 0},
#  {'code': 'AAGPX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 26.19,
#   'high': 26.19,
#   'low': 26.19,
#   'close': 26.19,
#   'adjusted_close': 26.19,
#   'volume': 0},
#  {'code': 'AAGR',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 13618},
#  {'code': 'AAGTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.72,
#   'high': 21.72,
#   'low': 21.72,
#   'close': 21.72,
#   'adjusted_close': 21.72,
#   'volume': 0},
#  {'code': 'AAHMX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.22,
#   'high': 9.22,
#   'low': 9.22,
#   'close': 9.22,
#   'adjusted_close': 9.22,
#   'volume': 0},
#  {'code': 'AAHTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.39,
#   'high': 22.39,
#   'low': 22.39,
#   'close': 22.39,
#   'adjusted_close': 22.39,
#   'volume': 0},
#  {'code': 'AAHYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.17,
#   'high': 7.17,
#   'low': 7.17,
#   'close': 7.17,
#   'adjusted_close': 7.17,
#   'volume': 0},
#  {'code': 'AAIAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.24,
#   'high': 20.24,
#   'low': 20.24,
#   'close': 20.24,
#   'adjusted_close': 20.24,
#   'volume': 0},
#  {'code': 'AAIDX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.39,
#   'high': 20.39,
#   'low': 20.39,
#   'close': 20.39,
#   'adjusted_close': 20.39,
#   'volume': 0},
#  {'code': 'AAIEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.93,
#   'high': 18.93,
#   'low': 18.93,
#   'close': 18.93,
#   'adjusted_close': 18.93,
#   'volume': 0},
#  {'code': 'AAIGF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.55,
#   'high': 7.4,
#   'low': 6.55,
#   'close': 7.05,
#   'adjusted_close': 7.05,
#   'volume': 106031},
#  {'code': 'AAIIQ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AAIIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.32,
#   'high': 7.32,
#   'low': 7.32,
#   'close': 7.32,
#   'adjusted_close': 7.32,
#   'volume': 0},
#  {'code': 'AAINX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.08,
#   'high': 9.08,
#   'low': 9.08,
#   'close': 9.08,
#   'adjusted_close': 9.08,
#   'volume': 0},
#  {'code': 'AAIRF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.134,
#   'high': 0.156,
#   'low': 0.1305,
#   'close': 0.1404,
#   'adjusted_close': 0.1404,
#   'volume': 12707},
#  {'code': 'AAISX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 19.38,
#   'high': 19.38,
#   'low': 19.38,
#   'close': 19.38,
#   'adjusted_close': 19.38,
#   'volume': 0},
#  {'code': 'AAL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.45,
#   'high': 16.74,
#   'low': 16.22,
#   'close': 16.72,
#   'adjusted_close': 16.72,
#   'volume': 23211943},
#  {'code': 'AALGX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 27.65,
#   'high': 27.65,
#   'low': 27.65,
#   'close': 27.65,
#   'adjusted_close': 27.65,
#   'volume': 0},
#  {'code': 'AALIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.62,
#   'high': 11.62,
#   'low': 11.62,
#   'close': 11.62,
#   'adjusted_close': 11.62,
#   'volume': 0},
#  {'code': 'AALRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 30.11,
#   'high': 30.11,
#   'low': 30.11,
#   'close': 30.11,
#   'adjusted_close': 30.11,
#   'volume': 0},
#  {'code': 'AALTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.07,
#   'high': 22.07,
#   'low': 22.07,
#   'close': 22.07,
#   'adjusted_close': 22.07,
#   'volume': 0},
#  {'code': 'AAM',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.18,
#   'high': 10.18,
#   'low': 10.07,
#   'close': 10.085,
#   'adjusted_close': 10.085,
#   'volume': 10100},
#  {'code': 'AAM-WT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0628,
#   'high': 0.0699,
#   'low': 0.0601,
#   'close': 0.0699,
#   'adjusted_close': 0.0699,
#   'volume': 7589},
#  {'code': 'AAMAF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0,
#   'high': 0,
#   'low': 0,
#   'close': 0,
#   'adjusted_close': 0,
#   'volume': 0},
#  {'code': 'AAMAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.12,
#   'high': 12.12,
#   'low': 12.12,
#   'close': 12.12,
#   'adjusted_close': 12.12,
#   'volume': 0},
#  {'code': 'AAMBX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.29,
#   'high': 10.29,
#   'low': 10.29,
#   'close': 10.29,
#   'adjusted_close': 10.29,
#   'volume': 0},
#  {'code': 'AAMCF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.75,
#   'high': 0.75,
#   'low': 0.75,
#   'close': 0.75,
#   'adjusted_close': 0.75,
#   'volume': 332},
#  {'code': 'AAMCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.36,
#   'high': 11.36,
#   'low': 11.36,
#   'close': 11.36,
#   'adjusted_close': 11.36,
#   'volume': 0},
#  {'code': 'AAME',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.46,
#   'high': 1.55,
#   'low': 1.45,
#   'close': 1.55,
#   'adjusted_close': 1.55,
#   'volume': 9089},
#  {'code': 'AAMIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.15,
#   'high': 12.15,
#   'low': 12.15,
#   'close': 12.15,
#   'adjusted_close': 12.15,
#   'volume': 0},
#  {'code': 'AAMMF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.1137,
#   'high': 0.1137,
#   'low': 0.11,
#   'close': 0.11,
#   'adjusted_close': 0.11,
#   'volume': 11500},
#  {'code': 'AAMTF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.26,
#   'high': 0.26,
#   'low': 0.26,
#   'close': 0.26,
#   'adjusted_close': 0.26,
#   'volume': 0},
#  {'code': 'AAMTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 27.77,
#   'high': 27.77,
#   'low': 27.77,
#   'close': 27.77,
#   'adjusted_close': 27.77,
#   'volume': 0},
#  {'code': 'AANNF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 3.35,
#   'high': 3.35,
#   'low': 3.35,
#   'close': 3.35,
#   'adjusted_close': 3.35,
#   'volume': 0},
#  {'code': 'AANTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.87,
#   'high': 18.87,
#   'low': 18.87,
#   'close': 18.87,
#   'adjusted_close': 18.87,
#   'volume': 0},
#  {'code': 'AAOI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 34.95,
#   'high': 35.005,
#   'low': 31.33,
#   'close': 32.11,
#   'adjusted_close': 32.11,
#   'volume': 3136455},
#  {'code': 'AAON',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 133.3,
#   'high': 133.58,
#   'low': 127.57,
#   'close': 128.67,
#   'adjusted_close': 128.67,
#   'volume': 445470},
#  {'code': 'AAOTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.38,
#   'high': 18.38,
#   'low': 18.38,
#   'close': 18.38,
#   'adjusted_close': 18.38,
#   'volume': 0},
#  {'code': 'AAP',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 43.53,
#   'high': 44.59,
#   'low': 43.225,
#   'close': 44.46,
#   'adjusted_close': 44.46,
#   'volume': 1455432},
#  {'code': 'AAPB',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 34,
#   'high': 34.83,
#   'low': 34,
#   'close': 34.76,
#   'adjusted_close': 34.76,
#   'volume': 50199},
#  {'code': 'AAPD',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.4,
#   'high': 15.44,
#   'low': 15.215,
#   'close': 15.23,
#   'adjusted_close': 15.23,
#   'volume': 128449},
#  {'code': 'AAPI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 5.25,
#   'high': 5.25,
#   'low': 5.25,
#   'close': 5.25,
#   'adjusted_close': 5.25,
#   'volume': 0},
#  {'code': 'AAPJ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0002,
#   'high': 0.0003,
#   'low': 0.0002,
#   'close': 0.0003,
#   'adjusted_close': 0.0003,
#   'volume': 1322000},
#  {'code': 'AAPL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 250.135,
#   'high': 253.81,
#   'low': 249.79,
#   'close': 253.48,
#   'adjusted_close': 253.48,
#   'volume': 51055731},
#  {'code': 'AAPR',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 26.495,
#   'high': 26.495,
#   'low': 26.495,
#   'close': 26.495,
#   'adjusted_close': 26.495,
#   'volume': 151},
#  {'code': 'AAPT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AAPU',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 38.11,
#   'high': 39.2,
#   'low': 38.03,
#   'close': 39.11,
#   'adjusted_close': 39.11,
#   'volume': 362678},
#  {'code': 'AAPX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 38.84,
#   'high': 39.97,
#   'low': 38.84,
#   'close': 39.96,
#   'adjusted_close': 39.96,
#   'volume': 40789},
#  {'code': 'AAPY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 28.89,
#   'high': 29.03,
#   'low': 28.89,
#   'close': 29.0193,
#   'adjusted_close': 29.0193,
#   'volume': 4286},
#  {'code': 'AAQL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.06,
#   'high': 1.06,
#   'low': 1.06,
#   'close': 1.06,
#   'adjusted_close': 1.06,
#   'volume': 0},
#  {'code': 'AARTY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.95,
#   'high': 12.95,
#   'low': 12.95,
#   'close': 12.95,
#   'adjusted_close': 12.95,
#   'volume': 0},
#  {'code': 'AASCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 31.67,
#   'high': 31.67,
#   'low': 31.67,
#   'close': 31.67,
#   'adjusted_close': 31.67,
#   'volume': 0},
#  {'code': 'AASMX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 24.51,
#   'high': 24.51,
#   'low': 24.51,
#   'close': 24.51,
#   'adjusted_close': 24.51,
#   'volume': 0},
#  {'code': 'AASOX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.62,
#   'high': 18.62,
#   'low': 18.62,
#   'close': 18.62,
#   'adjusted_close': 18.62,
#   'volume': 0},
#  {'code': 'AASP',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.5,
#   'high': 2.5,
#   'low': 2.49,
#   'close': 2.5,
#   'adjusted_close': 2.5,
#   'volume': 700},
#  {'code': 'AASRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 27.86,
#   'high': 27.86,
#   'low': 27.86,
#   'close': 27.86,
#   'adjusted_close': 27.86,
#   'volume': 0},
#  {'code': 'AASSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.68,
#   'high': 25.68,
#   'low': 25.68,
#   'close': 25.68,
#   'adjusted_close': 25.68,
#   'volume': 0},
#  {'code': 'AASTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.26,
#   'high': 9.26,
#   'low': 9.26,
#   'close': 9.26,
#   'adjusted_close': 9.26,
#   'volume': 0},
#  {'code': 'AASZF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.008,
#   'high': 0.014,
#   'low': 0.008,
#   'close': 0.014,
#   'adjusted_close': 0.014,
#   'volume': 130928},
#  {'code': 'AAT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 27.58,
#   'high': 27.73,
#   'low': 27.37,
#   'close': 27.5,
#   'adjusted_close': 27.5,
#   'volume': 297603},
#  {'code': 'AATC',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8,
#   'high': 8,
#   'low': 7.926,
#   'close': 7.93,
#   'adjusted_close': 7.93,
#   'volume': 17079},
#  {'code': 'AATGF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.001,
#   'high': 0.001,
#   'low': 0.001,
#   'close': 0.001,
#   'adjusted_close': 0.001,
#   'volume': 0},
#  {'code': 'AATIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.98,
#   'high': 20.98,
#   'low': 20.98,
#   'close': 20.98,
#   'adjusted_close': 20.98,
#   'volume': 0},
#  {'code': 'AATSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.68,
#   'high': 21.68,
#   'low': 21.68,
#   'close': 21.68,
#   'adjusted_close': 21.68,
#   'volume': 0},
#  {'code': 'AAUAF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0408,
#   'high': 0.0409,
#   'low': 0.04,
#   'close': 0.0409,
#   'adjusted_close': 0.0409,
#   'volume': 4454},
#  {'code': 'AAUCF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.47,
#   'high': 2.47,
#   'low': 2.36,
#   'close': 2.404,
#   'adjusted_close': 2.404,
#   'volume': 8400},
#  {'code': 'AAUTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 29.57,
#   'high': 29.57,
#   'low': 29.57,
#   'close': 29.57,
#   'adjusted_close': 29.57,
#   'volume': 0},
#  {'code': 'AAVMY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.158,
#   'high': 15.19,
#   'low': 15.1,
#   'close': 15.1,
#   'adjusted_close': 15.1,
#   'volume': 45300},
#  {'code': 'AAVVF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.03,
#   'high': 6.03,
#   'low': 5.88,
#   'close': 6,
#   'adjusted_close': 6,
#   'volume': 10118},
#  {'code': 'AAWEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.47,
#   'high': 14.47,
#   'low': 14.47,
#   'close': 14.47,
#   'adjusted_close': 14.47,
#   'volume': 0},
#  {'code': 'AAWH',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.403,
#   'high': 0.438,
#   'low': 0.403,
#   'close': 0.428,
#   'adjusted_close': 0.428,
#   'volume': 123700},
#  {'code': 'AAXJ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 73.47,
#   'high': 73.82,
#   'low': 73.3,
#   'close': 73.73,
#   'adjusted_close': 73.73,
#   'volume': 285398},
#  {'code': 'AAYYY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.05,
#   'high': 10.05,
#   'low': 10.05,
#   'close': 10.05,
#   'adjusted_close': 10.05,
#   'volume': 0},
#  {'code': 'AAZAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.39,
#   'high': 10.39,
#   'low': 10.39,
#   'close': 10.39,
#   'adjusted_close': 10.39,
#   'volume': 0},
#  {'code': 'AAZCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.38,
#   'high': 10.38,
#   'low': 10.38,
#   'close': 10.38,
#   'adjusted_close': 10.38,
#   'volume': 0},
#  {'code': 'AAZYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.4,
#   'high': 10.4,
#   'low': 10.4,
#   'close': 10.4,
#   'adjusted_close': 10.4,
#   'volume': 0},
#  {'code': 'AB',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 35.5,
#   'high': 35.77,
#   'low': 35.19,
#   'close': 35.45,
#   'adjusted_close': 35.45,
#   'volume': 968197},
#  {'code': 'ABAEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.67,
#   'high': 8.67,
#   'low': 8.67,
#   'close': 8.67,
#   'adjusted_close': 8.67,
#   'volume': 0},
#  {'code': 'ABALX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 35.08,
#   'high': 35.08,
#   'low': 35.08,
#   'close': 35.08,
#   'adjusted_close': 35.08,
#   'volume': 0},
#  {'code': 'ABASX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.48,
#   'high': 21.48,
#   'low': 21.48,
#   'close': 21.48,
#   'adjusted_close': 21.48,
#   'volume': 0},
#  {'code': 'ABAT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.8834,
#   'high': 0.918,
#   'low': 0.83,
#   'close': 0.86,
#   'adjusted_close': 0.86,
#   'volume': 534069},
#  {'code': 'ABAUX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.93,
#   'high': 9.93,
#   'low': 9.93,
#   'close': 9.93,
#   'adjusted_close': 9.93,
#   'volume': 0},
#  {'code': 'ABBNY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 57.75,
#   'high': 58.15,
#   'low': 57.74,
#   'close': 57.83,
#   'adjusted_close': 57.83,
#   'volume': 22298},
#  {'code': 'ABBRF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.71,
#   'high': 1.72,
#   'low': 1.63,
#   'close': 1.7,
#   'adjusted_close': 1.7,
#   'volume': 68337},
#  {'code': 'ABBV',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 170.58,
#   'high': 176.5,
#   'low': 170.21,
#   'close': 175.38,
#   'adjusted_close': 175.38,
#   'volume': 7664728},
#  {'code': 'ABBY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0,
#   'high': 0,
#   'low': 0,
#   'close': 0,
#   'adjusted_close': 0,
#   'volume': 0},
#  {'code': 'ABCAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.62,
#   'high': 23.62,
#   'low': 23.62,
#   'close': 23.62,
#   'adjusted_close': 23.62,
#   'volume': 0},
#  {'code': 'ABCB',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 66.37,
#   'high': 67.03,
#   'low': 65.34,
#   'close': 65.36,
#   'adjusted_close': 65.36,
#   'volume': 315713},
#  {'code': 'ABCCF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 4.24,
#   'high': 4.24,
#   'low': 4.24,
#   'close': 4.24,
#   'adjusted_close': 4.24,
#   'volume': 0},
#  {'code': 'ABCCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 13.12,
#   'high': 13.12,
#   'low': 13.12,
#   'close': 13.12,
#   'adjusted_close': 13.12,
#   'volume': 0},
#  {'code': 'ABCE',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'ABCEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.63,
#   'high': 8.63,
#   'low': 8.63,
#   'close': 8.63,
#   'adjusted_close': 8.63,
#   'volume': 0},
#  {'code': 'ABCFF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0136,
#   'high': 0.0136,
#   'low': 0.0136,
#   'close': 0.0136,
#   'adjusted_close': 0.0136,
#   'volume': 103333},
#  {'code': 'ABCIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.92,
#   'high': 23.92,
#   'low': 23.92,
#   'close': 23.92,
#   'adjusted_close': 23.92,
#   'volume': 0},
#  {'code': 'ABCL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.9,
#   'high': 2.93,
#   'low': 2.77,
#   'close': 2.79,
#   'adjusted_close': 2.79,
#   'volume': 2140140},
#  {'code': 'ABCP',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.305,
#   'high': 0.305,
#   'low': 0.305,
#   'close': 0.305,
#   'adjusted_close': 0.305,
#   'volume': 25},
#  {'code': 'ABCS',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 29.52,
#   'high': 29.52,
#   'low': 29.3799,
#   'close': 29.4056,
#   'adjusted_close': 29.4056,
#   'volume': 2392},
#  {'code': 'ABCSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 17.15,
#   'high': 17.15,
#   'low': 17.15,
#   'close': 17.15,
#   'adjusted_close': 17.15,
#   'volume': 0},
#  {'code': 'ABCYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.76,
#   'high': 23.76,
#   'low': 23.76,
#   'close': 23.76,
#   'adjusted_close': 23.76,
#   'volume': 0},
#  {'code': 'ABDAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.33,
#   'high': 9.33,
#   'low': 9.33,
#   'close': 9.33,
#   'adjusted_close': 9.33,
#   'volume': 0},
#  {'code': 'ABDBY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 4.04,
#   'high': 4.04,
#   'low': 4.04,
#   'close': 4.04,
#   'adjusted_close': 4.04,
#   'volume': 0},
#  {'code': 'ABDDF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 33,
#   'high': 33,
#   'low': 33,
#   'close': 33,
#   'adjusted_close': 33,
#   'volume': 0},
#  {'code': 'ABECX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.42,
#   'high': 23.42,
#   'low': 23.42,
#   'close': 23.42,
#   'adjusted_close': 23.42,
#   'volume': 0},
#  {'code': 'ABEIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.93,
#   'high': 8.93,
#   'low': 8.93,
#   'close': 8.93,
#   'adjusted_close': 8.93,
#   'volume': 0},
#  {'code': 'ABEMX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 13.95,
#   'high': 13.95,
#   'low': 13.95,
#   'close': 13.95,
#   'adjusted_close': 13.95,
#   'volume': 0},
#  {'code': 'ABEO',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 5.86,
#   'high': 6,
#   'low': 5.81,
#   'close': 5.88,
#   'adjusted_close': 5.88,
#   'volume': 154162},
#  {'code': 'ABEPF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0139,
#   'high': 0.0139,
#   'low': 0.0139,
#   'close': 0.0139,
#   'adjusted_close': 0.0139,
#   'volume': 330},
#  {'code': 'ABEQ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 32.24,
#   'high': 32.24,
#   'low': 32.175,
#   'close': 32.2,
#   'adjusted_close': 32.2,
#   'volume': 7792},
#  {'code': 'ABESX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.93,
#   'high': 8.93,
#   'low': 8.93,
#   'close': 8.93,
#   'adjusted_close': 8.93,
#   'volume': 0},
#  {'code': 'ABEV',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.09,
#   'high': 2.14,
#   'low': 2.07,
#   'close': 2.12,
#   'adjusted_close': 2.12,
#   'volume': 35940760},
#  {'code': 'ABEYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 19.97,
#   'high': 19.97,
#   'low': 19.97,
#   'close': 19.97,
#   'adjusted_close': 19.97,
#   'volume': 0},
#  {'code': 'ABFAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.88,
#   'high': 12.88,
#   'low': 12.88,
#   'close': 12.88,
#   'adjusted_close': 12.88,
#   'volume': 0},
#  {'code': 'ABFL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 68.88,
#   'high': 69.07,
#   'low': 68.824,
#   'close': 69.016,
#   'adjusted_close': 69.016,
#   'volume': 23500},
#  {'code': 'ABG',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 254.66,
#   'high': 256.9,
#   'low': 251.84,
#   'close': 252.3,
#   'adjusted_close': 252.3,
#   'volume': 182721},
#  {'code': 'ABGNX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.15,
#   'high': 20.15,
#   'low': 20.15,
#   'close': 20.15,
#   'adjusted_close': 20.15,
#   'volume': 0},
#  {'code': 'ABGOF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0,
#   'high': 0,
#   'low': 0,
#   'close': 0,
#   'adjusted_close': 0,
#   'volume': 0},
#  {'code': 'ABGSF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.61,
#   'high': 0.61,
#   'low': 0.61,
#   'close': 0.61,
#   'adjusted_close': 0.61,
#   'volume': 0},
#  {'code': 'ABHFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.41,
#   'high': 15.41,
#   'low': 15.41,
#   'close': 15.41,
#   'adjusted_close': 15.41,
#   'volume': 0},
#  {'code': 'ABHTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.27,
#   'high': 9.27,
#   'low': 9.27,
#   'close': 9.27,
#   'adjusted_close': 9.27,
#   'volume': 0},
#  {'code': 'ABHY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.33,
#   'high': 21.33,
#   'low': 21.33,
#   'close': 21.33,
#   'adjusted_close': 21.33,
#   'volume': 100},
#  {'code': 'ABIAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 13.92,
#   'high': 13.92,
#   'low': 13.92,
#   'close': 13.92,
#   'adjusted_close': 13.92,
#   'volume': 0},
#  {'code': 'ABICX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 13.85,
#   'high': 13.85,
#   'low': 13.85,
#   'close': 13.85,
#   'adjusted_close': 13.85,
#   'volume': 0},
#  {'code': 'ABIEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.59,
#   'high': 8.59,
#   'low': 8.59,
#   'close': 8.59,
#   'adjusted_close': 8.59,
#   'volume': 0},
#  {'code': 'ABILF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0,
#   'high': 0,
#   'low': 0,
#   'close': 0,
#   'adjusted_close': 0,
#   'volume': 0},
#  {'code': 'ABIMX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.85,
#   'high': 9.85,
#   'low': 9.85,
#   'close': 9.85,
#   'adjusted_close': 9.85,
#   'volume': 0},
#  {'code': 'ABINX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.16,
#   'high': 20.16,
#   'low': 20.16,
#   'close': 20.16,
#   'adjusted_close': 20.16,
#   'volume': 0},
#  {'code': 'ABIT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.1195,
#   'high': 0.14,
#   'low': 0.1081,
#   'close': 0.1225,
#   'adjusted_close': 0.1225,
#   'volume': 684070},
#  {'code': 'ABIYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.25,
#   'high': 14.25,
#   'low': 14.25,
#   'close': 14.25,
#   'adjusted_close': 14.25,
#   'volume': 0},
#  {'code': 'ABIZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.28,
#   'high': 22.28,
#   'low': 22.28,
#   'close': 22.28,
#   'adjusted_close': 22.28,
#   'volume': 0},
#  {'code': 'ABL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.86,
#   'high': 8.05,
#   'low': 7.68,
#   'close': 7.7,
#   'adjusted_close': 7.7,
#   'volume': 273822},
#  {'code': 'ABLD',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 30.8,
#   'high': 30.8,
#   'low': 30.7,
#   'close': 30.724,
#   'adjusted_close': 30.724,
#   'volume': 2900},
#  {'code': 'ABLG',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 29.57,
#   'high': 29.58,
#   'low': 29.47,
#   'close': 29.536,
#   'adjusted_close': 29.536,
#   'volume': 16300},
#  {'code': 'ABLLL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 26.67,
#   'high': 27.09,
#   'low': 26.63,
#   'close': 26.68,
#   'adjusted_close': 26.68,
#   'volume': 2200},
#  {'code': 'ABLLW',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.16,
#   'high': 1.19,
#   'low': 1.11,
#   'close': 1.12,
#   'adjusted_close': 1.12,
#   'volume': 28998},
#  {'code': 'ABLOX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.58,
#   'high': 22.58,
#   'low': 22.58,
#   'close': 22.58,
#   'adjusted_close': 22.58,
#   'volume': 0},
#  {'code': 'ABLSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.39,
#   'high': 14.39,
#   'low': 14.39,
#   'close': 14.39,
#   'adjusted_close': 14.39,
#   'volume': 0},
#  {'code': 'ABLT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 88,
#   'high': 88,
#   'low': 88,
#   'close': 88,
#   'adjusted_close': 88,
#   'volume': 100},
#  {'code': 'ABLV',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.704,
#   'high': 0.7351,
#   'low': 0.7,
#   'close': 0.735,
#   'adjusted_close': 0.735,
#   'volume': 2457},
#  {'code': 'ABLYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 29.73,
#   'high': 29.73,
#   'low': 29.73,
#   'close': 29.73,
#   'adjusted_close': 29.73,
#   'volume': 0},
#  {'code': 'ABLZF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 57.46,
#   'high': 59.17,
#   'low': 57.46,
#   'close': 59.17,
#   'adjusted_close': 59.17,
#   'volume': 2300},
#  {'code': 'ABM',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 56.32,
#   'high': 56.545,
#   'low': 54.67,
#   'close': 54.91,
#   'adjusted_close': 54.91,
#   'volume': 436139},
#  {'code': 'ABMC',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 39800},
#  {'code': 'ABMIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.45,
#   'high': 22.45,
#   'low': 22.45,
#   'close': 22.45,
#   'adjusted_close': 22.45,
#   'volume': 0},
#  {'code': 'ABMRF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.72,
#   'high': 14.72,
#   'low': 14.72,
#   'close': 14.72,
#   'adjusted_close': 14.72,
#   'volume': 4000},
#  {'code': 'ABMT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0006,
#   'high': 0.0006,
#   'low': 0.0006,
#   'close': 0.0006,
#   'adjusted_close': 0.0006,
#   'volume': 0},
#  {'code': 'ABNAF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0451,
#   'high': 0.0451,
#   'low': 0.0451,
#   'close': 0.0451,
#   'adjusted_close': 0.0451,
#   'volume': 0},
#  {'code': 'ABNAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.35,
#   'high': 10.35,
#   'low': 10.35,
#   'close': 10.35,
#   'adjusted_close': 10.35,
#   'volume': 0},
#  {'code': 'ABNB',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 132.2,
#   'high': 132.61,
#   'low': 130.88,
#   'close': 132.24,
#   'adjusted_close': 132.24,
#   'volume': 3126163},
#  {'code': 'ABNCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.99,
#   'high': 9.99,
#   'low': 9.99,
#   'close': 9.99,
#   'adjusted_close': 9.99,
#   'volume': 0},
#  {'code': 'ABNDX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.24,
#   'high': 11.24,
#   'low': 11.24,
#   'close': 11.24,
#   'adjusted_close': 11.24,
#   'volume': 0},
#  {'code': 'ABNFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.24,
#   'high': 11.24,
#   'low': 11.24,
#   'close': 11.24,
#   'adjusted_close': 11.24,
#   'volume': 0},
#  {'code': 'ABNIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 30.96,
#   'high': 30.96,
#   'low': 30.96,
#   'close': 30.96,
#   'adjusted_close': 30.96,
#   'volume': 0},
#  {'code': 'ABNOX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.1,
#   'high': 10.1,
#   'low': 10.1,
#   'close': 10.1,
#   'adjusted_close': 10.1,
#   'volume': 0},
#  {'code': 'ABNTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.09,
#   'high': 10.09,
#   'low': 10.09,
#   'close': 10.09,
#   'adjusted_close': 10.09,
#   'volume': 0},
#  {'code': 'ABNY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.06,
#   'high': 15.07,
#   'low': 14.91,
#   'close': 15,
#   'adjusted_close': 15,
#   'volume': 29500},
#  {'code': 'ABNYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.37,
#   'high': 10.37,
#   'low': 10.37,
#   'close': 10.37,
#   'adjusted_close': 10.37,
#   'volume': 0},
#  {'code': 'ABNZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.14,
#   'high': 10.14,
#   'low': 10.14,
#   'close': 10.14,
#   'adjusted_close': 10.14,
#   'volume': 0},
#  {'code': 'ABOS',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.97,
#   'high': 2.0299,
#   'low': 1.91,
#   'close': 1.96,
#   'adjusted_close': 1.96,
#   'volume': 361491},
#  {'code': 'ABP',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.4206,
#   'high': 1.4239,
#   'low': 1.266,
#   'close': 1.348,
#   'adjusted_close': 1.348,
#   'volume': 214},
#  {'code': 'ABPAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.44,
#   'high': 12.44,
#   'low': 12.44,
#   'close': 12.44,
#   'adjusted_close': 12.44,
#   'volume': 0},
#  {'code': 'ABPCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.31,
#   'high': 12.31,
#   'low': 12.31,
#   'close': 12.31,
#   'adjusted_close': 12.31,
#   'volume': 0},
#  {'code': 'ABPR',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'ABPRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 90.96,
#   'high': 90.96,
#   'low': 90.96,
#   'close': 90.96,
#   'adjusted_close': 90.96,
#   'volume': 0},
#  {'code': 'ABPWW',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.03,
#   'high': 0.03,
#   'low': 0.0297,
#   'close': 0.03,
#   'adjusted_close': 0.03,
#   'volume': 2109},
#  {'code': 'ABPYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.57,
#   'high': 12.57,
#   'low': 12.57,
#   'close': 12.57,
#   'adjusted_close': 12.57,
#   'volume': 0},
#  {'code': 'ABPZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.48,
#   'high': 12.48,
#   'low': 12.48,
#   'close': 12.48,
#   'adjusted_close': 12.48,
#   'volume': 0},
#  {'code': 'ABQCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.27,
#   'high': 9.27,
#   'low': 9.27,
#   'close': 9.27,
#   'adjusted_close': 9.27,
#   'volume': 0},
#  {'code': 'ABQIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.31,
#   'high': 9.31,
#   'low': 9.31,
#   'close': 9.31,
#   'adjusted_close': 9.31,
#   'volume': 0},
#  {'code': 'ABQQ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0008,
#   'high': 0.001,
#   'low': 0.0007,
#   'close': 0.0009,
#   'adjusted_close': 0.0009,
#   'volume': 68757862},
#  {'code': 'ABQUX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.3,
#   'high': 9.3,
#   'low': 9.3,
#   'close': 9.3,
#   'adjusted_close': 9.3,
#   'volume': 0},
#  {'code': 'ABQYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.3,
#   'high': 9.3,
#   'low': 9.3,
#   'close': 9.3,
#   'adjusted_close': 9.3,
#   'volume': 0},
#  {'code': 'ABQZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.32,
#   'high': 9.32,
#   'low': 9.32,
#   'close': 9.32,
#   'adjusted_close': 9.32,
#   'volume': 0},
#  {'code': 'ABR',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 14.38,
#   'high': 14.52,
#   'low': 14.21,
#   'close': 14.22,
#   'adjusted_close': 14.22,
#   'volume': 1852240},
#  {'code': 'ABR-P-D',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 19.31,
#   'high': 19.31,
#   'low': 19.0311,
#   'close': 19.05,
#   'adjusted_close': 19.05,
#   'volume': 10818},
#  {'code': 'ABR-P-E',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.6,
#   'high': 18.65,
#   'low': 18.5628,
#   'close': 18.65,
#   'adjusted_close': 18.65,
#   'volume': 3581},
#  {'code': 'ABR-P-F',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.7,
#   'high': 22.94,
#   'low': 22.5,
#   'close': 22.94,
#   'adjusted_close': 22.94,
#   'volume': 18327},
#  {'code': 'ABR-PD',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 19.31,
#   'high': 19.31,
#   'low': 19.0311,
#   'close': 19.05,
#   'adjusted_close': 19.05,
#   'volume': 10818},
#  {'code': 'ABR-PE',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.65,
#   'high': 18.65,
#   'low': 18.5628,
#   'close': 18.65,
#   'adjusted_close': 18.65,
#   'volume': 3581},
#  {'code': 'ABR-PF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.7799,
#   'high': 22.94,
#   'low': 22.5,
#   'close': 22.94,
#   'adjusted_close': 22.94,
#   'volume': 18327},
#  {'code': 'ABRCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.3,
#   'high': 7.3,
#   'low': 7.3,
#   'close': 7.3,
#   'adjusted_close': 7.3,
#   'volume': 0},
#  {'code': 'ABRFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.16,
#   'high': 16.16,
#   'low': 16.16,
#   'close': 16.16,
#   'adjusted_close': 16.16,
#   'volume': 0},
#  {'code': 'ABRIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.17,
#   'high': 8.17,
#   'low': 8.17,
#   'close': 8.17,
#   'adjusted_close': 8.17,
#   'volume': 0},
#  {'code': 'ABRJX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.31,
#   'high': 8.31,
#   'low': 8.31,
#   'close': 8.31,
#   'adjusted_close': 8.31,
#   'volume': 0},
#  {'code': 'ABRMF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.25,
#   'high': 0.25,
#   'low': 0.25,
#   'close': 0.25,
#   'adjusted_close': 0.25,
#   'volume': 0},
#  {'code': 'ABRRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.69,
#   'high': 7.69,
#   'low': 7.69,
#   'close': 7.69,
#   'adjusted_close': 7.69,
#   'volume': 0},
#  {'code': 'ABRSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.51,
#   'high': 8.51,
#   'low': 8.51,
#   'close': 8.51,
#   'adjusted_close': 8.51,
#   'volume': 0},
#  {'code': 'ABRTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.64,
#   'high': 11.64,
#   'low': 11.64,
#   'close': 11.64,
#   'adjusted_close': 11.64,
#   'volume': 0},
#  {'code': 'ABRUX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.04,
#   'high': 15.04,
#   'low': 15.04,
#   'close': 15.04,
#   'adjusted_close': 15.04,
#   'volume': 0},
#  {'code': 'ABRVX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 12.05,
#   'high': 12.05,
#   'low': 12.05,
#   'close': 12.05,
#   'adjusted_close': 12.05,
#   'volume': 0},
#  {'code': 'ABRWX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 18.5,
#   'high': 18.5,
#   'low': 18.5,
#   'close': 18.5,
#   'adjusted_close': 18.5,
#   'volume': 0},
#  {'code': 'ABRYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.16,
#   'high': 8.16,
#   'low': 8.16,
#   'close': 8.16,
#   'adjusted_close': 8.16,
#   'volume': 0},
#  {'code': 'ABRZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.92,
#   'high': 7.92,
#   'low': 7.92,
#   'close': 7.92,
#   'adjusted_close': 7.92,
#   'volume': 0},
#  {'code': 'ABSAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.37,
#   'high': 25.37,
#   'low': 25.37,
#   'close': 25.37,
#   'adjusted_close': 25.37,
#   'volume': 0},
#  {'code': 'ABSCF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.89,
#   'high': 0.89,
#   'low': 0.89,
#   'close': 0.89,
#   'adjusted_close': 0.89,
#   'volume': 0},
#  {'code': 'ABSI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 3.75,
#   'high': 3.859,
#   'low': 3.32,
#   'close': 3.33,
#   'adjusted_close': 3.33,
#   'volume': 2323501},
#  {'code': 'ABSIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.18,
#   'high': 21.18,
#   'low': 21.18,
#   'close': 21.18,
#   'adjusted_close': 21.18,
#   'volume': 0},
#  {'code': 'ABSOF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.11,
#   'high': 0.11,
#   'low': 0.11,
#   'close': 0.11,
#   'adjusted_close': 0.11,
#   'volume': 0},
#  {'code': 'ABSSF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.66,
#   'high': 2.66,
#   'low': 2.66,
#   'close': 2.66,
#   'adjusted_close': 2.66,
#   'volume': 400},
#  {'code': 'ABSTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.23,
#   'high': 25.23,
#   'low': 25.23,
#   'close': 25.23,
#   'adjusted_close': 25.23,
#   'volume': 0},
# ...
#   'open': 2.05,
#   'high': 2.05,
#   'low': 2.05,
#   'close': 2.05,
#   'adjusted_close': 2.05,
#   'volume': 0},
#  {'code': 'AGLYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 16.28,
#   'high': 16.28,
#   'low': 16.28,
#   'close': 16.28,
#   'adjusted_close': 16.28,
#   'volume': 0},
#  {'code': 'AGM',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 208.33,
#   'high': 209.23,
#   'low': 207.425,
#   'close': 209.19,
#   'adjusted_close': 209.19,
#   'volume': 35405},
#  {'code': 'AGM-A',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 157.7401,
#   'high': 157.7401,
#   'low': 157.7401,
#   'close': 157.7401,
#   'adjusted_close': 157.7401,
#   'volume': 215},
#  {'code': 'AGM-P-D',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.0204,
#   'high': 23.1157,
#   'low': 22.97,
#   'close': 23.0762,
#   'adjusted_close': 23.0762,
#   'volume': 4174},
#  {'code': 'AGM-P-E',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.23,
#   'high': 23.23,
#   'low': 23.23,
#   'close': 23.23,
#   'adjusted_close': 23.23,
#   'volume': 305},
#  {'code': 'AGM-P-F',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.83,
#   'high': 20.93,
#   'low': 20.7199,
#   'close': 20.93,
#   'adjusted_close': 20.93,
#   'volume': 11244},
#  {'code': 'AGM-PD',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.0204,
#   'high': 23.1157,
#   'low': 22.97,
#   'close': 23.0762,
#   'adjusted_close': 23.0762,
#   'volume': 4174},
#  {'code': 'AGM-PE',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.23,
#   'high': 23.23,
#   'low': 23.23,
#   'close': 23.23,
#   'adjusted_close': 23.23,
#   'volume': 305},
#  {'code': 'AGM-PF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 20.7199,
#   'high': 20.93,
#   'low': 20.7199,
#   'close': 20.93,
#   'adjusted_close': 20.93,
#   'volume': 11244},
#  {'code': 'AGM-PG',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 19.3,
#   'high': 19.38,
#   'low': 19.2105,
#   'close': 19.37,
#   'adjusted_close': 19.37,
#   'volume': 8037},
#  {'code': 'AGMH',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.6603,
#   'high': 1.77,
#   'low': 1.6,
#   'close': 1.68,
#   'adjusted_close': 1.68,
#   'volume': 124710},
#  {'code': 'AGMHX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.85,
#   'high': 8.85,
#   'low': 8.85,
#   'close': 8.85,
#   'adjusted_close': 8.85,
#   'volume': 0},
#  {'code': 'AGMI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 26.8391,
#   'high': 26.8391,
#   'low': 26.8391,
#   'close': 26.8391,
#   'adjusted_close': 26.8391,
#   'volume': 5},
#  {'code': 'AGMNX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.85,
#   'high': 8.85,
#   'low': 8.85,
#   'close': 8.85,
#   'adjusted_close': 8.85,
#   'volume': 0},
#  {'code': 'AGMRF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0323,
#   'high': 0.0323,
#   'low': 0.0265,
#   'close': 0.0294,
#   'adjusted_close': 0.0294,
#   'volume': 1091061},
#  {'code': 'AGMWX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.84,
#   'high': 8.84,
#   'low': 8.84,
#   'close': 8.84,
#   'adjusted_close': 8.84,
#   'volume': 0},
#  {'code': 'AGNC',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.63,
#   'high': 9.72,
#   'low': 9.56,
#   'close': 9.57,
#   'adjusted_close': 9.57,
#   'volume': 15993125},
#  {'code': 'AGNCL',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.237,
#   'high': 25.285,
#   'low': 25.1,
#   'close': 25.27,
#   'adjusted_close': 25.27,
#   'volume': 9500},
#  {'code': 'AGNCM',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.42,
#   'high': 25.42,
#   'low': 25.3,
#   'close': 25.42,
#   'adjusted_close': 25.42,
#   'volume': 6430},
#  {'code': 'AGNCN',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.641,
#   'high': 25.75,
#   'low': 25.64,
#   'close': 25.75,
#   'adjusted_close': 25.75,
#   'volume': 12279},
#  {'code': 'AGNCO',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.46,
#   'high': 25.49,
#   'low': 25.45,
#   'close': 25.46,
#   'adjusted_close': 25.46,
#   'volume': 20345},
#  {'code': 'AGNCP',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 24.83,
#   'high': 24.9,
#   'low': 24.76,
#   'close': 24.78,
#   'adjusted_close': 24.78,
#   'volume': 10535},
#  {'code': 'AGNG',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 30.76,
#   'high': 30.99,
#   'low': 30.76,
#   'close': 30.99,
#   'adjusted_close': 30.99,
#   'volume': 4244},
#  {'code': 'AGNPF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.048,
#   'high': 0.048,
#   'low': 0.041,
#   'close': 0.041,
#   'adjusted_close': 0.041,
#   'volume': 1918},
#  {'code': 'AGNY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.048,
#   'high': 0.048,
#   'low': 0.048,
#   'close': 0.048,
#   'adjusted_close': 0.048,
#   'volume': 0},
#  {'code': 'AGO',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 90,
#   'high': 90.16,
#   'low': 88.17,
#   'close': 88.91,
#   'adjusted_close': 88.91,
#   'volume': 360928},
#  {'code': 'AGOAF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AGOCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.82,
#   'high': 11.82,
#   'low': 11.82,
#   'close': 11.82,
#   'adjusted_close': 11.82,
#   'volume': 0},
#  {'code': 'AGOIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.97,
#   'high': 6.97,
#   'low': 6.97,
#   'close': 6.97,
#   'adjusted_close': 6.97,
#   'volume': 0},
#  {'code': 'AGORX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.65,
#   'high': 9.65,
#   'low': 9.65,
#   'close': 9.65,
#   'adjusted_close': 9.65,
#   'volume': 0},
#  {'code': 'AGOVX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.96,
#   'high': 6.96,
#   'low': 6.96,
#   'close': 6.96,
#   'adjusted_close': 6.96,
#   'volume': 0},
#  {'code': 'AGOX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 29.25,
#   'high': 29.4,
#   'low': 28.96,
#   'close': 28.96,
#   'adjusted_close': 28.96,
#   'volume': 17037},
#  {'code': 'AGOZX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.87,
#   'high': 21.87,
#   'low': 21.87,
#   'close': 21.87,
#   'adjusted_close': 21.87,
#   'volume': 0},
#  {'code': 'AGPYY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 4.9,
#   'high': 4.9,
#   'low': 4.9,
#   'close': 4.9,
#   'adjusted_close': 4.9,
#   'volume': 0},
#  {'code': 'AGQ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 37.43,
#   'high': 37.84,
#   'low': 36.86,
#   'close': 37.74,
#   'adjusted_close': 37.74,
#   'volume': 963800},
#  {'code': 'AGQI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 13.86,
#   'high': 13.9,
#   'low': 13.85,
#   'close': 13.86,
#   'adjusted_close': 13.86,
#   'volume': 4944},
#  {'code': 'AGQIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.92,
#   'high': 8.92,
#   'low': 8.92,
#   'close': 8.92,
#   'adjusted_close': 8.92,
#   'volume': 0},
#  {'code': 'AGQRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.92,
#   'high': 8.92,
#   'low': 8.92,
#   'close': 8.92,
#   'adjusted_close': 8.92,
#   'volume': 0},
#  {'code': 'AGR',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 35.6,
#   'high': 35.7,
#   'low': 35.6,
#   'close': 35.63,
#   'adjusted_close': 35.63,
#   'volume': 593177},
#  {'code': 'AGRCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.62,
#   'high': 10.62,
#   'low': 10.62,
#   'close': 10.62,
#   'adjusted_close': 10.62,
#   'volume': 0},
#  {'code': 'AGRDF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AGRDX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 62.93,
#   'high': 62.93,
#   'low': 62.93,
#   'close': 62.93,
#   'adjusted_close': 62.93,
#   'volume': 0},
#  {'code': 'AGREF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.08,
#   'high': 0.08,
#   'low': 0.08,
#   'close': 0.08,
#   'adjusted_close': 0.08,
#   'volume': 0},
#  {'code': 'AGRFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 114.45,
#   'high': 114.45,
#   'low': 114.45,
#   'close': 114.45,
#   'adjusted_close': 114.45,
#   'volume': 0},
#  {'code': 'AGRH',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 25.975,
#   'high': 25.975,
#   'low': 25.975,
#   'close': 25.975,
#   'adjusted_close': 25.975,
#   'volume': 200},
#  {'code': 'AGRI',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 2.08,
#   'high': 2.2999,
#   'low': 2.03,
#   'close': 2.24,
#   'adjusted_close': 2.24,
#   'volume': 717739},
#  {'code': 'AGRO',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 10.23,
#   'high': 10.27,
#   'low': 10.035,
#   'close': 10.11,
#   'adjusted_close': 10.11,
#   'volume': 635420},
#  {'code': 'AGRPF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 8.11,
#   'high': 8.11,
#   'low': 8.11,
#   'close': 8.11,
#   'adjusted_close': 8.11,
#   'volume': 0},
#  {'code': 'AGRPY',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 21.86,
#   'high': 21.86,
#   'low': 21.86,
#   'close': 21.86,
#   'adjusted_close': 21.86,
#   'volume': 300},
#  {'code': 'AGRS',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.01,
#   'high': 0.01,
#   'low': 0.01,
#   'close': 0.01,
#   'adjusted_close': 0.01,
#   'volume': 0},
#  {'code': 'AGRUF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 9.65,
#   'high': 9.65,
#   'low': 9.65,
#   'close': 9.65,
#   'adjusted_close': 9.65,
#   'volume': 0},
#  {'code': 'AGRYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 136.43,
#   'high': 136.43,
#   'low': 136.43,
#   'close': 136.43,
#   'adjusted_close': 136.43,
#   'volume': 0},
#  {'code': 'AGS',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.44,
#   'high': 11.52,
#   'low': 11.44,
#   'close': 11.52,
#   'adjusted_close': 11.52,
#   'volume': 80353},
#  {'code': 'AGSCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.71,
#   'high': 6.71,
#   'low': 6.71,
#   'close': 6.71,
#   'adjusted_close': 6.71,
#   'volume': 0},
#  {'code': 'AGSVF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0025,
#   'high': 0.0025,
#   'low': 0.0025,
#   'close': 0.0025,
#   'adjusted_close': 0.0025,
#   'volume': 0},
#  {'code': 'AGTEF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0202,
#   'high': 0.0202,
#   'low': 0.0202,
#   'close': 0.0202,
#   'adjusted_close': 0.0202,
#   'volume': 0},
#  {'code': 'AGTFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 15.79,
#   'high': 15.79,
#   'low': 15.79,
#   'close': 15.79,
#   'adjusted_close': 15.79,
#   'volume': 0},
#  {'code': 'AGTHX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 84.59,
#   'high': 84.59,
#   'low': 84.59,
#   'close': 84.59,
#   'adjusted_close': 84.59,
#   'volume': 0},
#  {'code': 'AGTIX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 161.38,
#   'high': 161.38,
#   'low': 161.38,
#   'close': 161.38,
#   'adjusted_close': 161.38,
#   'volume': 0},
#  {'code': 'AGTK',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0001,
#   'high': 0.0001,
#   'low': 0.0001,
#   'close': 0.0001,
#   'adjusted_close': 0.0001,
#   'volume': 0},
#  {'code': 'AGTT',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.12,
#   'high': 0.12,
#   'low': 0.095,
#   'close': 0.095,
#   'adjusted_close': 0.095,
#   'volume': 31000},
#  {'code': 'AGTX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.1701,
#   'high': 0.175,
#   'low': 0.1601,
#   'close': 0.1601,
#   'adjusted_close': 0.1601,
#   'volume': 1300},
#  {'code': 'AGUAX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 7.14,
#   'high': 7.14,
#   'low': 7.14,
#   'close': 7.14,
#   'adjusted_close': 7.14,
#   'volume': 0},
#  {'code': 'AGVCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.97,
#   'high': 6.97,
#   'low': 6.97,
#   'close': 6.97,
#   'adjusted_close': 6.97,
#   'volume': 0},
#  {'code': 'AGVDX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.83,
#   'high': 23.83,
#   'low': 23.83,
#   'close': 23.83,
#   'adjusted_close': 23.83,
#   'volume': 0},
#  {'code': 'AGVEX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.99,
#   'high': 23.99,
#   'low': 23.99,
#   'close': 23.99,
#   'adjusted_close': 23.99,
#   'volume': 0},
#  {'code': 'AGVFX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 23.98,
#   'high': 23.98,
#   'low': 23.98,
#   'close': 23.98,
#   'adjusted_close': 23.98,
#   'volume': 0},
#  {'code': 'AGVGX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 24.04,
#   'high': 24.04,
#   'low': 24.04,
#   'close': 24.04,
#   'adjusted_close': 24.04,
#   'volume': 0},
#  {'code': 'AGVHX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 24.07,
#   'high': 24.07,
#   'low': 24.07,
#   'close': 24.07,
#   'adjusted_close': 24.07,
#   'volume': 0},
#  {'code': 'AGVRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.97,
#   'high': 6.97,
#   'low': 6.97,
#   'close': 6.97,
#   'adjusted_close': 6.97,
#   'volume': 0},
#  {'code': 'AGVSX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.97,
#   'high': 6.97,
#   'low': 6.97,
#   'close': 6.97,
#   'adjusted_close': 6.97,
#   'volume': 0},
#  {'code': 'AGVYX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 6.97,
#   'high': 6.97,
#   'low': 6.97,
#   'close': 6.97,
#   'adjusted_close': 6.97,
#   'volume': 0},
#  {'code': 'AGWRX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 53.44,
#   'high': 53.44,
#   'low': 53.44,
#   'close': 53.44,
#   'adjusted_close': 53.44,
#   'volume': 0},
#  {'code': 'AGWUX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 62.68,
#   'high': 62.68,
#   'low': 62.68,
#   'close': 62.68,
#   'adjusted_close': 62.68,
#   'volume': 0},
#  {'code': 'AGX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 144.96,
#   'high': 147.62,
#   'low': 140.0701,
#   'close': 146.66,
#   'adjusted_close': 146.66,
#   'volume': 310952},
#  {'code': 'AGXKF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 1.2487,
#   'high': 1.2487,
#   'low': 1.2487,
#   'close': 1.2487,
#   'adjusted_close': 1.2487,
#   'volume': 250},
#  {'code': 'AGXPF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.141,
#   'high': 0.1465,
#   'low': 0.1372,
#   'close': 0.1372,
#   'adjusted_close': 0.1372,
#   'volume': 96350},
#  {'code': 'AGYCX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.76,
#   'high': 11.76,
#   'low': 11.76,
#   'close': 11.76,
#   'adjusted_close': 11.76,
#   'volume': 0},
#  {'code': 'AGYGX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 11.64,
#   'high': 11.64,
#   'low': 11.64,
#   'close': 11.64,
#   'adjusted_close': 11.64,
#   'volume': 0},
#  {'code': 'AGYP',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.0034,
#   'high': 0.0051,
#   'low': 0.0034,
#   'close': 0.0043,
#   'adjusted_close': 0.0043,
#   'volume': 117599},
#  {'code': 'AGYS',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 139.22,
#   'high': 142.64,
#   'low': 135.935,
#   'close': 141.74,
#   'adjusted_close': 141.74,
#   'volume': 421851},
#  {'code': 'AGYTF',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 0.052,
#   'high': 0.052,
#   'low': 0.052,
#   'close': 0.052,
#   'adjusted_close': 0.052,
#   'volume': 0},
#  {'code': 'AGYWX',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 63.05,
#   'high': 63.05,
#   'low': 63.05,
#   'close': 63.05,
#   'adjusted_close': 63.05,
#   'volume': 0},
#  {'code': 'AGZ',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 108.55,
#   'high': 108.71,
#   'low': 108.435,
#   'close': 108.64,
#   'adjusted_close': 108.64,
#   'volume': 50544},
#  {'code': 'AGZD',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 22.63,
#   'high': 22.63,
#   'low': 22.4901,
#   'close': 22.53,
#   'adjusted_close': 22.53,
#   'volume': 24428},
#  ...]

# %%
len(data)
# Out:
# 41445

# %%
result = [item for item in data if item['code'] == 'NVDA']
result
# Out:
# [{'code': 'NVDA',
#   'exchange_short_name': 'US',
#   'date': '2024-12-17',
#   'open': 129.09,
#   'high': 131.59,
#   'low': 126.86,
#   'close': 130.39,
#   'adjusted_close': 130.39,
#   'volume': 259410263}]

# %%
df = pd.DataFrame(data)
df
# Out:
#              code exchange_short_name        date      open      high  \
# 0      0P0001NGF5                  US  2024-12-17    9.4792    9.4792
# 1               A                  US  2024-12-17  137.5800  139.3400
# 2              AA                  US  2024-12-17   38.0000   38.8700
# 3             AAA                  US  2024-12-17   25.1600   25.1600
# 4           AAAAX                  US  2024-12-17   12.0600   12.0600
# ...           ...                 ...         ...       ...       ...
# 41440         ZWS                  US  2024-12-17   39.2800   39.4700
# 41441        ZYME                  US  2024-12-17   13.5500   13.8400
# 41442        ZYXI                  US  2024-12-17    8.4500    8.6200
# 41443       ZZHGF                  US  2024-12-17    2.4000    2.4000
# 41444         ZZZ                  US  2024-12-17   29.2000   29.2400
#
#             low     close  adjusted_close   volume
# 0        9.4792    9.4792          9.4792        0
# 1      136.2000  136.4600        136.4600  2430600
# 2       37.5300   38.4400         38.4400  4420300
# 3       25.1300   25.1500         25.1500     8190
# 4       12.0600   12.0600         12.0600        0
# ...         ...       ...             ...      ...
# 41440   38.9600   38.9800         38.9800   850568
# 41441   13.0800   13.3700         13.3700   494102
# 41442    8.3600    8.4000          8.4000    97000
# 41443    2.4000    2.4000          2.4000        0
# 41444   29.0794   29.0847         29.0847     3372
#
# [41445 rows x 9 columns]

# %% [markdown]
# ## All Splits Bulk EOD

# %%
import requests
import pandas as pd
import numpy as np

YOUR_API_TOKEN = '64ba54ca4a54b5.70340846'

url = f'https://eodhd.com/api/eod-bulk-last-day/US?api_token={YOUR_API_TOKEN}&type=splits&fmt=json'
splits = requests.get(url).json()

splits
# Out:
# [{'code': 'BWNAD',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'split': '1.000000/20.000000'},
#  {'code': 'CMGHF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'split': '1.000000/20.000000'}]

# %% [markdown]
# ## All Dividends Bulk EOD

# %%
url = f'https://eodhd.com/api/eod-bulk-last-day/US?api_token={YOUR_API_TOKEN}&type=dividends&fmt=json'
dividends = requests.get(url).json()
dividends
# Out:
# [{'code': 'AKRYY',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '3.82353',
#   'currency': 'USD',
#   'declarationDate': '2024-10-31',
#   'recordDate': '2024-11-23',
#   'paymentDate': '2024-12-16',
#   'period': 'Annual',
#   'unadjustedValue': '3.8235300000'},
#  {'code': 'APH',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.16500',
#   'currency': 'USD',
#   'declarationDate': '2024-10-31',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2025-01-08',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.1650000000'},
#  {'code': 'ARES',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.93000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-01',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.9300000000'},
#  {'code': 'ATVDY',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.22082',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.2208200000'},
#  {'code': 'AVIV',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.65080',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.6508000000'},
#  {'code': 'BBY',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.94000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-26',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2025-01-07',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.9400000000'},
#  {'code': 'BSDGY',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.38547',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.3854700000'},
#  {'code': 'BTHM',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.18110',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.1811000000'},
#  {'code': 'CHSCL',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.46875',
#   'currency': 'USD',
#   'declarationDate': '2024-11-05',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.4687500000'},
#  {'code': 'CHSCP',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.50000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-05',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.5000000000'},
#  {'code': 'COMT',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '1.24012',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '1.2401200000'},
#  {'code': 'CRBG',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.23000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-04',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.2300000000'},
#  {'code': 'DFAE',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.14815',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.1481500000'},
#  {'code': 'ECL',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.65000',
#   'currency': 'USD',
#   'declarationDate': '2024-12-05',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2025-01-15',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.6500000000'},
#  {'code': 'ELNRF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '6.74300',
#   'currency': 'USD',
#   'declarationDate': '2024-10-30',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-18',
#   'period': 'SemiAnnual',
#   'unadjustedValue': '6.7430000000'},
#  {'code': 'ESGY',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.04140',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.0414000000'},
#  {'code': 'EXCOF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.07490',
#   'currency': 'USD',
#   'declarationDate': '2024-11-27',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.0749000000'},
#  {'code': 'FDUS',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.61000',
#   'currency': 'USD',
#   'declarationDate': '2024-10-31',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-27',
#   'period': 'QUARTERLY',
#   'unadjustedValue': '0.6100000000'},
#  {'code': 'FG',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.22000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-07',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.2200000000'},
#  {'code': 'FINS',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.10900',
#   'currency': 'USD',
#   'declarationDate': '2024-12-03',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.1090000000'},
#  {'code': 'FMOCY',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.78096',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.7809600000'},
#  {'code': 'FNF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.50000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': '2024-12-31',
#   'period': None,
#   'unadjustedValue': '0.5000000000'},
#  {'code': 'GCHEF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.03180',
#   'currency': 'USD',
#   'declarationDate': '2024-04-08',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-18',
#   'period': 'Other',
#   'unadjustedValue': '0.0318000000'},
#  {'code': 'GNMLF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.20000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.2000000000'},
#  {'code': 'HKBNF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.16500',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.1650000000'},
#  {'code': 'ICLN',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.11418',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.1141800000'},
#  {'code': 'IIM',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.07710',
#   'currency': 'USD',
#   'declarationDate': '2024-12-02',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0771000000'},
#  {'code': 'IMCG',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.16803',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.1680300000'},
#  {'code': 'IQI',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.06310',
#   'currency': 'USD',
#   'declarationDate': '2024-12-02',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0631000000'},
#  {'code': 'KBDCF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.05130',
#   'currency': 'USD',
#   'declarationDate': '2024-08-26',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2025-01-08',
#   'period': 'SemiAnnual',
#   'unadjustedValue': '0.0513000000'},
#  {'code': 'KWEB',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '1.02495',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '1.0249500000'},
#  {'code': 'LNDAF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.01378',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.0137800000'},
#  {'code': 'MALJF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.01800',
#   'currency': 'USD',
#   'declarationDate': '2024-11-01',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.0180000000'},
#  {'code': 'MCEM',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '2.50000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '2.5000000000'},
#  {'code': 'MEOH',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.18500',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.1850000000'},
#  {'code': 'MMT',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.03385',
#   'currency': 'USD',
#   'declarationDate': '2024-12-02',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0338500000'},
#  {'code': 'MONTF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.02000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.0200000000'},
#  {'code': 'NAT',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.04000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-29',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2025-01-16',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.0400000000'},
#  {'code': 'NMFC',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.32000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.3200000000'},
#  {'code': 'OIA',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.02910',
#   'currency': 'USD',
#   'declarationDate': '2024-12-02',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0291000000'},
#  {'code': 'OLED',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.40000',
#   'currency': 'USD',
#   'declarationDate': '2024-10-30',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.4000000000'},
#  {'code': 'OXLC',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.09000',
#   'currency': 'USD',
#   'declarationDate': '2024-07-25',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0900000000'},
#  {'code': 'OXLCN',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.14844',
#   'currency': 'USD',
#   'declarationDate': '2024-11-01',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.1484400000'},
#  {'code': 'OXLCO',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.12500',
#   'currency': 'USD',
#   'declarationDate': '2024-11-01',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.1250000000'},
#  {'code': 'OXLCP',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.13021',
#   'currency': 'USD',
#   'declarationDate': '2024-11-01',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.1302100000'},
#  {'code': 'OXSQ',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.03500',
#   'currency': 'USD',
#   'declarationDate': '2024-08-08',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0350000000'},
#  {'code': 'PCF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.06220',
#   'currency': 'USD',
#   'declarationDate': '2024-09-25',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0622000000'},
#  {'code': 'PDCC',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.22000',
#   'currency': 'USD',
#   'declarationDate': '2024-11-04',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.2200000000'},
#  {'code': 'PPSI',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '1.50000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '1.5000000000'},
#  {'code': 'RYN',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.28500',
#   'currency': 'USD',
#   'declarationDate': '2024-10-21',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.2850000000'},
#  {'code': 'SPE',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.09540',
#   'currency': 'USD',
#   'declarationDate': '2024-09-26',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0954000000'},
#  {'code': 'STM',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.09000',
#   'currency': 'USD',
#   'declarationDate': '2024-03-21',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-27',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.0900000000'},
#  {'code': 'STMEF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.09000',
#   'currency': 'USD',
#   'declarationDate': '2024-03-21',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-18',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.0900000000'},
#  {'code': 'SUSA',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.37023',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.3702300000'},
#  {'code': 'TCPC',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.34000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.3400000000'},
#  {'code': 'UNJCF',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.06000',
#   'currency': 'USD',
#   'declarationDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'period': None,
#   'unadjustedValue': '0.0600000000'},
#  {'code': 'UNTC',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '3.25000',
#   'currency': 'USD',
#   'declarationDate': '2024-12-06',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-27',
#   'period': 'QUARTERLY',
#   'unadjustedValue': '3.2500000000'},
#  {'code': 'VCV',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.06460',
#   'currency': 'USD',
#   'declarationDate': '2024-12-02',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0646000000'},
#  {'code': 'VICI',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.43250',
#   'currency': 'USD',
#   'declarationDate': '2024-12-05',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2025-01-09',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.4325000000'},
#  {'code': 'VVR',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.04300',
#   'currency': 'USD',
#   'declarationDate': '2024-12-02',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-31',
#   'period': 'Monthly',
#   'unadjustedValue': '0.0430000000'},
#  {'code': 'WAL-PA',
#   'exchange': 'US',
#   'date': '2024-12-17',
#   'dividend': '0.26560',
#   'currency': 'USD',
#   'declarationDate': '2024-10-31',
#   'recordDate': '2024-12-17',
#   'paymentDate': '2024-12-30',
#   'period': 'Quarterly',
#   'unadjustedValue': '0.2656000000'}]

# %% [markdown]
# # Historical data

# %% [markdown]
# Please note, that OHLC we provide in raw adjusted neither to splits nor to dividends,
# ***while adjusted closes are adjusted to both splits and dividends, and volume is adjusted to splits.
#
# If you need OHLC adjusted only to splits then it’s better to use our Technical API with the ‘function=splitadjusted’ parameter.

# %% [markdown]
# MCD.US consists of two parts: {SYMBOL_NAME}.{EXCHANGE_ID}, then you can use, for example, MCD.MX for Mexican Stock Exchange. or MCD.US for NYSE. Check the list of supported exchanges to get more information about the stock markets we do support.
#
# api_token – your own API KEY, which you will get after you subscribe to our services.
# fmt – the output format. Possible values are ‘csv’ for CSV output and ‘json’ for JSON output. Default value: ‘csv’.
# period – use ‘d’ for daily, ‘w’ for weekly, ‘m’ for monthly prices. By default, daily prices will be shown. Data aggregated weekly and monthly also shows weekly and monthly volume.
# order – use ‘a’ for ascending dates (from old to new), ‘d’ for descending dates (from new to old). By default, dates are shown in ascending order.
# from and to – the format is ‘YYYY-MM-DD’. If you need data from Jan 5, 2017, to Feb 10, 2017, you should use from=2017-01-05 and to=2017-02-10.m

# %%
import requests
import json

YOUR_API_TOKEN = '64ba54ca4a54b5.70340846'

url = f'https://eodhd.com/api/eod/NVDA.US?from=2010-01-01&to=2024-12-18&period=d&api_token={YOUR_API_TOKEN}&fmt=json'
nvda = requests.get(url).content

# Decode the byte string and load JSON
decoded_data = json.loads(nvda.decode('utf-8'))
nvda = pd.DataFrame(decoded_data)
nvda
# Out:
# b'[{"date":"2010-01-04","open":18.51,"high":18.62,"low":18.11,"close":18.49,"adjusted_close":0.4239,"volume":800352792},{"date":"2010-01-05","open":18.42,"high":18.96,"low":18.42,"close":18.76,"adjusted_close":0.4301,"volume":728697553},{"date":"2010-01-06","open":18.75,"high":18.92,"low":18.57,"close":18.88,"adjusted_close":0.4328,"volume":649166794},{"date":"2010-01-07","open":18.78,"high":18.86,"low":18.37,"close":18.51,"adjusted_close":0.4244,"volume":547790035},{"date":"2010-01-08","open":18.36,"high":18.682,"low":18.25,"close":18.55,"adjusted_close":0.4253,"volume":478175995},{"date":"2010-01-11","open":18.65,"high":18.73,"low":18.03,"close":18.29,"adjusted_close":0.4193,"volume":556655154},{"date":"2010-01-12","open":18.02,"high":18.09,"low":17.29,"close":17.67,"adjusted_close":0.4051,"volume":627488754},{"date":"2010-01-13","open":17.79,"high":17.97,"low":17.1,"close":17.91,"adjusted_close":0.4106,"volume":508945195},{"date":"2010-01-14","open":17.69,"high":17.82,"low":17.33,"close":17.63,"adjusted_close":0.4042,"volume":608803194},{"date":"2010-01-15","open":17.5,"high":17.65,"low":16.88,"close":17.11,"adjusted_close":0.3923,"volume":818248832},{"date":"2010-01-19","open":16.98,"high":17.54,"low":16.93,"close":17.43,"adjusted_close":0.3996,"volume":545334035},{"date":"2010-01-20","open":17.21,"high":17.43,"low":16.98,"close":17.355,"adjusted_close":0.3979,"volume":719737953},{"date":"2010-01-21","open":17.35,"high":17.66,"low":16.89,"close":17.05,"adjusted_close":0.3909,"volume":608631634},{"date":"2010-01-22","open":16.85,"high":17.16,"low":16.36,"close":16.46,"adjusted_close":0.3774,"volume":1067982789},{"date":"2010-01-25","open":16.73,"high":17.06,"low":16.61,"close":16.74,"adjusted_close":0.3838,"volume":643673594},{"date":"2010-01-26","open":16.66,"high":16.77,"low":16.2,"close":16.21,"adjusted_close":0.3716,"volume":714692793},{"date":"2010-01-27","open":16.2,"high":16.71,"low":16.02,"close":16.65,"adjusted_close":0.3817,"volume":812530792},{"date":"2010-01-28","open":16.78,"high":16.84,"low":15.86,"close":16.09,"adjusted_close":0.3689,"volume":687817553},{"date":"2010-01-29","open":16.27,"high":16.45,"low":15.15,"close":15.39,"adjusted_close":0.3528,"volume":774707552},{"date":"2010-02-01","open":15.45,"high":16.6,"low":15.32,"close":16.57,"adjusted_close":0.3799,"volume":949829591},{"date":"2010-02-02","open":16.51,"high":16.95,"low":16.46,"close":16.74,"adjusted_close":0.3838,"volume":849812032},{"date":"2010-02-03","open":16.59,"high":16.95,"low":16.51,"close":16.88,"adjusted_close":0.387,"volume":562298834},{"date":"2010-02-04","open":16.73,"high":16.73,"low":15.72,"close":15.9,"adjusted_close":0.3645,"volume":783477192},{"date":"2010-02-05","open":15.88,"high":16.26,"low":15.6,"close":16.22,"adjusted_close":0.3719,"volume":604852794},{"date":"2010-02-08","open":16.17,"high":16.58,"low":15.873,"close":16.19,"adjusted_close":0.3712,"volume":445164396},{"date":"2010-02-09","open":16.45,"high":16.53,"low":15.9,"close":16.06,"adjusted_close":0.3682,"volume":930159991},{"date":"2010-02-10","open":16.16,"high":16.52,"low":16.05,"close":16.37,"adjusted_close":0.3753,"volume":535824395},{"date":"2010-02-11","open":16.63,"high":17.3,"low":16.51,"close":17.12,"adjusted_close":0.3925,"volume":696002033},{"date":"2010-02-12","open":17,"high":17.7,"low":16.805,"close":17.35,"adjusted_close":0.3978,"volume":780215232},{"date":"2010-02-16","open":17.58,"high":17.74,"low":17.37,"close":17.67,"adjusted_close":0.4051,"volume":457183595},{"date":"2010-02-17","open":17.89,"high":17.9,"low":17.325,"close":17.84,"adjusted_close":0.409,"volume":876556391},{"date":"2010-02-18","open":16.86,"high":16.95,"low":16.21,"close":16.67,"adjusted_close":0.3822,"volume":1515759985},{"date":"2010-02-19","open":16.6,"high":16.78,"low":16.5,"close":16.58,"adjusted_close":0.3801,"volume":510624395},{"date":"2010-02-22","open":16.65,"high":16.9,"low":16.5,"close":16.61,"adjusted_close":0.3808,"volume":458122395},{"date":"2010-02-23","open":16.6 ...

# %% [markdown]
# # EODHD ADJ CLOSE = ADJ for SPLIT + DIV

# %%
import json

# Decode the byte string and load JSON
decoded_data = json.loads(nvda.decode('utf-8'))
nvda = pd.DataFrame(decoded_data)
nvda
# Out:
#             date    open     high     low   close  adjusted_close     volume
# 0     2010-01-04   18.51   18.620   18.11   18.49          0.4239  800352792
# 1     2010-01-05   18.42   18.960   18.42   18.76          0.4301  728697553
# 2     2010-01-06   18.75   18.920   18.57   18.88          0.4328  649166794
# 3     2010-01-07   18.78   18.860   18.37   18.51          0.4244  547790035
# 4     2010-01-08   18.36   18.682   18.25   18.55          0.4253  478175995
# ...          ...     ...      ...     ...     ...             ...        ...
# 3760  2024-12-11  137.36  140.170  135.21  139.31        139.3100  184905203
# 3761  2024-12-12  137.08  138.440  135.80  137.34        137.3400  159211391
# 3762  2024-12-13  138.94  139.600  132.54  134.25        134.2500  231514891
# 3763  2024-12-16  134.18  134.400  130.42  132.00        132.0000  237951109
# 3764  2024-12-17  129.09  131.590  126.86  130.39        130.3900  259410263
#
# [3765 rows x 7 columns]

# %%
nvda.to_csv('nvda_eodhd.csv')

# %%
#Comparing Yfin vs EODHD data
stock_data = stock_data.copy().round(4)
stock_data
# Out:
# Price       Adj Close     Close      High       Low      Open     Volume
# Date
# 2010-01-04     0.4239    0.4622    0.4655    0.4527    0.4627  800204000
# 2010-01-05     0.4301    0.4690    0.4740    0.4605    0.4605  728648000
# 2010-01-06     0.4329    0.4720    0.4730    0.4642    0.4688  649168000
# 2010-01-07     0.4244    0.4627    0.4715    0.4593    0.4695  547792000
# 2010-01-08     0.4253    0.4638    0.4670    0.4563    0.4590  478168000
# ...               ...       ...       ...       ...       ...        ...
# 2024-12-11   139.3100  139.3100  140.1700  135.2100  137.3600  184905200
# 2024-12-12   137.3400  137.3400  138.4400  135.8000  137.0800  159211400
# 2024-12-13   134.2500  134.2500  139.6000  132.5400  138.9400  231514900
# 2024-12-16   132.0000  132.0000  134.4000  130.4200  134.1800  237951100
# 2024-12-17   130.3900  130.3900  131.5900  126.8600  129.0900  258219700
#
# [3765 rows x 6 columns]

# %%
import pandas as pd
import requests
from sqlalchemy import create_engine, text
import numpy as np
from datetime import date, timedelta, datetime
import pytz

# Database configuration
server =
database = 
username =
password = 
api_key = '64ba54ca4a54b5.70340846'

# Create database engine
engine = create_engine(f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server")

# Exchange operating hours in SGT (UTC+8)
exchange_hours = {
    "JK": {"open": "09:00", "close": "16:15"},  # Indonesia Stock Exchange
    "TW": {"open": "09:00", "close": "13:30"},  # Taiwan Stock Exchange
    "HK": {"open": "09:30", "close": "16:00"},  # Hong Kong Stock Exchange
    "US": {"open": "22:30", "close": "05:00"},  # NYSE/NASDAQ (Next Day in SGT)
    "KLSE": {"open": "09:00", "close": "17:00"},  # Bursa Malaysia
    "SHG": {"open": "09:30", "close": "15:00"},  # Shanghai Stock Exchange
}

def calculate_rsi(data, period=14):
    """Calculate RSI for a given DataFrame of OHLC data."""
    delta = data['Close'].diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.ewm(alpha=1 / period, min_periods=period).mean()
    avg_loss = loss.ewm(alpha=1 / period, min_periods=period).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi.round(2)

def sanitize_row(row):
    """Sanitize row values for database insertion."""
    row = row.copy()
    for key in row.keys():
        if isinstance(row[key], float) and (np.isnan(row[key]) or np.isinf(row[key])):
            row[key] = None
    return row

def delete_old_data(engine, cutoff_date):
    """Delete data older than the cutoff date."""
    try:
        with engine.connect() as conn:
            delete_query = text("""
                DELETE FROM HistoricalPrices
                WHERE Date < :cutoff_date;
            """)
            conn.execute(delete_query, {"cutoff_date": cutoff_date})
        print(f"Deleted data older than {cutoff_date}.")
    except Exception as e:
        print(f"Error deleting old data: {e}")

def get_last_market_date():
    """Get the last working day (non-weekend)."""
    today = datetime.today().date()
    while today.weekday() > 4:  # Saturday (5) or Sunday (6)
        today -= timedelta(days=1)
    return today

def get_latest_working_day():
    """Get the latest working day (excluding weekends)."""
    today = datetime.now(pytz.timezone("Asia/Singapore"))
    if today.weekday() == 5:  # Saturday
        return (today - timedelta(days=1)).strftime("%Y-%m-%d")
    elif today.weekday() == 6:  # Sunday
        return (today - timedelta(days=2)).strftime("%Y-%m-%d")
    return today.strftime("%Y-%m-%d")

def is_market_closed(exchange):
    """Check if the market is closed for a specific exchange."""
    now = datetime.now(pytz.timezone("Asia/Singapore"))

    open_time = datetime.strptime(exchange_hours[exchange]["open"], "%H:%M").time()
    close_time = datetime.strptime(exchange_hours[exchange]["close"], "%H:%M").time()

    # Market is closed if the current time is after close_time
    if close_time < open_time:  # Handle markets closing past midnight (e.g., US)
        return now.time() > close_time or now.time() < open_time
    else:
        return now.time() > close_time

def update_historical_prices_and_rsi(engine, tickers, start_date, end_date):
    """Fetch missing historical data and calculate RSI."""
    for ticker in tickers:
        print(f"Fetching data for {ticker} from {start_date} to {end_date}")
        url = f"https://eodhd.com/api/eod/{ticker}?from={start_date}&to={end_date}&period=d&api_token={api_key}&fmt=json"
        response = requests.get(url)

        if response.status_code != 200:
            print(f"Failed to fetch data for {ticker}. Status: {response.status_code}")
            continue

        data = response.json()
        if not data:
            print(f"No data returned for {ticker}.")
            continue

        #print(f"Data fetched for {ticker}: {data}")
        df = pd.DataFrame(data)

        # Ensure required columns exist
        required_columns = ['date', 'open', 'high', 'low', 'close', 'adjusted_close', 'volume']
        if not all(col in df.columns for col in required_columns):
            print(f"Data for {ticker} is missing required columns. Skipping.")
            continue

        df.rename(columns={
            'date': 'Date',
            'open': 'Open',
            'high': 'High',
            'low': 'Low',
            'close': 'Close',
            'adjusted_close': 'AdjustedClose',
            'volume': 'Volume'
        }, inplace=True)

        df['Ticker'] = ticker
        df['RSI'] = calculate_rsi(df)

        # Insert data into database
        with engine.connect() as conn:
            for _, row in df.iterrows():
                row = sanitize_row(row)
                #print(f"Inserting/Updating row for {ticker}: {row}")
                insert_query = text("""
                    INSERT INTO HistoricalPrices ([Ticker], [Date], [Open], [High], [Low], [Close], [AdjustedClose], [Volume], [RSI])
VALUES (:Ticker, :Date, :Open, :High, :Low, :Close, :AdjustedClose, :Volume, :RSI);
                """)
                conn.execute(insert_query, {
                    "Ticker": row['Ticker'],
                    "Date": row['Date'],
                    "Open": row['Open'],
                    "High": row['High'],
                    "Low": row['Low'],
                    "Close": row['Close'],
                    "AdjustedClose": row['AdjustedClose'],
                    "Volume": row['Volume'],
                    "RSI": row['RSI']
                })

    print(f"Update complete for tickers: {tickers}")

def run_daily_update():
    """Run daily updates for all US tickers and maintain 3 years of data."""
    try:
        last_market_date = get_last_market_date()  # Get the last valid market date
        print(f"Last market date: {last_market_date}")

        # Fetch tickers with outdated data for US market
        outdated_query = text("""
            SELECT Ticker, MAX(Date) AS LatestDate
            FROM HistoricalPrices
            WHERE Ticker LIKE '%.US'  -- Filter for US tickers
            GROUP BY Ticker
            HAVING MAX(Date) <= :last_market_date
        """)
        with engine.connect() as conn:
            outdated_tickers = pd.read_sql(outdated_query, conn, params={"last_market_date": last_market_date})

        if outdated_tickers.empty:
            print("All tickers are up-to-date.")
            return

        print(f"Found {len(outdated_tickers)} tickers with outdated data.")

        for _, row in outdated_tickers.iterrows():
            ticker = row['Ticker']
            last_date = row['LatestDate']
            update_historical_prices_and_rsi(engine, [ticker], last_date + timedelta(days=1), last_market_date)

    except Exception as e:
        print(f"Error running daily update: {e}")

#Run Daily update
run_daily_update()

# %% [markdown]
# # YFIN ADJ CLOSE = ADJ for SPLIT + DIV

# %% [markdown]
# ## YFIN OHLC ALSO ADJ for SPLIT + DIV

# %%
import yfinance as yf

stock_data = yf.download("NVDA", start='2010-01-01', end='2024-12-18')
stock_data.columns = stock_data.columns.droplevel(1)
stock_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Date
# 2010-01-04    0.423923    0.462250    0.465500    0.452750    0.462750
# 2010-01-05    0.430113    0.469000    0.474000    0.460500    0.460500
# 2010-01-06    0.432864    0.472000    0.473000    0.464250    0.468750
# 2010-01-07    0.424381    0.462750    0.471500    0.459250    0.469500
# 2010-01-08    0.425298    0.463750    0.467000    0.456250    0.459000
# ...                ...         ...         ...         ...         ...
# 2024-12-11  139.309998  139.309998  140.169998  135.210007  137.360001
# 2024-12-12  137.339996  137.339996  138.440002  135.800003  137.080002
# 2024-12-13  134.250000  134.250000  139.600006  132.539993  138.940002
# 2024-12-16  132.000000  132.000000  134.399994  130.419998  134.179993
# 2024-12-17  130.389999  130.389999  131.589996  126.860001  129.089996
#
# Price          Volume
# Date
# 2010-01-04  800204000
# 2010-01-05  728648000
# 2010-01-06  649168000
# 2010-01-07  547792000
# 2010-01-08  478168000
# ...               ...
# 2024-12-11  184905200
# 2024-12-12  159211400
# 2024-12-13  231514900
# 2024-12-16  237951100
# 2024-12-17  258219700
#
# [3765 rows x 6 columns]

# %% [markdown]
# # Tradingview "UNADJ" ADJ for SPLITS
# # ADJ adjusts for dividends
